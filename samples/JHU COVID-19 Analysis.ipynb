# %% [markdown]
# ## Johns Hopkins CSSE COVID-19 Analysis
# This notebook processes and performs quick analysis from the [2019 Novel Coronavirus COVID-19 (2019-nCoV) Data Repository by Johns Hopkins CSSE](https://github.com/CSSEGISandData/COVID-19).  The data is updated in the `/databricks-datasets/COVID/CSSEGISandData/` location regularly so you can access the data directly.

# %%
# Standard Libraries
import io

# External Libraries
import requests
import numpy as np
import pandas as pd
import altair as alt
from vega_datasets import data

# topographical
topo_usa = 'https://vega.github.io/vega-datasets/data/us-10m.json'
topo_wa = 'https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/WA-53-washington-counties.json'
topo_king = 'https://raw.githubusercontent.com/johan/world.geo.json/master/countries/USA/WA/King.geo.json'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/jinja2/runtime.py:318: DeprecationWarning: Using or importing the ABCs from &#39;collections&#39; instead of from &#39;collections.abc&#39; is deprecated, and in 3.8 it will stop working
#   from collections import Mapping
# </div>

# %% [markdown]
# ## Specify `jhu_daily` table
# * Source: `/databricks-datasets/COVID/CSSEGISandData/csse_covid_19_data/csse_covid_19_daily_reports/`
# * Contains the COVID-19 daily reports

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DoubleType, DateType, TimestampType
schema = StructType([
  StructField('FIPS', IntegerType(), True), 
  StructField('Admin2', StringType(), True),
  StructField('Province_State', StringType(), True),  
  StructField('Country_Region', StringType(), True),  
  StructField('Last_Update', TimestampType(), True),  
  StructField('Lat', DoubleType(), True),  
  StructField('Long_', DoubleType(), True),
  StructField('Confirmed', IntegerType(), True), 
  StructField('Deaths', IntegerType(), True), 
  StructField('Recovered', IntegerType(), True), 
  StructField('Active', IntegerType(), True),   
  StructField('Combined_Key', StringType(), True),  
  StructField('process_date', DateType(), True),    
])

# Create initial empty Spark DataFrame based on preceding schema
jhu_daily = spark.createDataFrame([], schema)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Loops Through Each File
# The following code snippet processes each file to:
# * Extract out the filename which is needed to know which date the data is referring
# * The schema of the files change over time so we need slightly different logic to insert data for each different schema

# %%
import os
import pandas as pd
import glob
from pyspark.sql.functions import input_file_name, lit, col

# Creates a list of all csv files
globbed_files = glob.glob("/dbfs/databricks-datasets/COVID/CSSEGISandData/csse_covid_19_data/csse_covid_19_daily_reports/*.csv") 
#globbed_files = glob.glob("/dbfs/databricks-datasets/COVID/CSSEGISandData/csse_covid_19_data/csse_covid_19_daily_reports/04*.csv")

i = 0
for csv in globbed_files:
  # Filename
  source_file = csv[5:200]
  process_date = csv[100:104] + "-" + csv[94:96] + "-" + csv[97:99]
  
  # Read data into temporary dataframe
  df_tmp = spark.read.option("inferSchema", True).option("header", True).csv(source_file)
  df_tmp.createOrReplaceTempView("df_tmp")

  # Obtain schema
  schema_txt = ' '.join(map(str, df_tmp.columns)) 
  
  # Three schema types (as of 2020-04-08) 
  schema_01 = "Province/State Country/Region Last Update Confirmed Deaths Recovered" # 01-22-2020 to 02-29-2020
  schema_02 = "Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude" # 03-01-2020 to 03-21-2020
  schema_03 = "FIPS Admin2 Province_State Country_Region Last_Update Lat Long_ Confirmed Deaths Recovered Active Combined_Key" # 03-22-2020 to
  
  # Insert data based on schema type
  if (schema_txt == schema_01):
    df_tmp = (df_tmp
                .withColumn("FIPS", lit(None).cast(IntegerType()))
                .withColumn("Admin2", lit(None).cast(StringType()))
                .withColumn("Province_State", col("Province/State"))
                .withColumn("Country_Region", col("Country/Region"))
                .withColumn("Last_Update", col("Last Update"))
                .withColumn("Lat", lit(None).cast(DoubleType()))
                .withColumn("Long_", lit(None).cast(DoubleType()))
                .withColumn("Active", lit(None).cast(IntegerType()))
                .withColumn("Combined_Key", lit(None).cast(StringType()))
                .withColumn("process_date", lit(process_date))
                .select("FIPS", 
                        "Admin2", 
                        "Province_State", 
                        "Country_Region", 
                        "Last_Update", 
                        "Lat", 
                        "Long_", 
                        "Confirmed", 
                        "Deaths", 
                        "Recovered", 
                        "Active", 
                        "Combined_Key", 
                        "process_date")
               )
    jhu_daily = jhu_daily.union(df_tmp)
  elif (schema_txt == schema_02):
    df_tmp = (df_tmp
                .withColumn("FIPS", lit(None).cast(IntegerType()))
                .withColumn("Admin2", lit(None).cast(StringType()))
                .withColumn("Province_State", col("Province/State"))
                .withColumn("Country_Region", col("Country/Region"))
                .withColumn("Last_Update", col("Last Update"))
                .withColumn("Lat", col("Latitude"))
                .withColumn("Long_", col("Longitude"))
                .withColumn("Active", lit(None).cast(IntegerType()))
                .withColumn("Combined_Key", lit(None).cast(StringType()))
                .withColumn("process_date", lit(process_date))
                .select("FIPS", 
                        "Admin2", 
                        "Province_State", 
                        "Country_Region", 
                        "Last_Update", 
                        "Lat", 
                        "Long_", 
                        "Confirmed", 
                        "Deaths", 
                        "Recovered", 
                        "Active", 
                        "Combined_Key", 
                        "process_date")
               )
    jhu_daily = jhu_daily.union(df_tmp)

  elif (schema_txt == schema_03):
    df_tmp = df_tmp.withColumn("process_date", lit(process_date))
    jhu_daily = jhu_daily.union(df_tmp)
  else:
    print("Schema may have changed")
    raise
  
  # print out the schema being processed by date
  print("%s | %s" % (process_date, schema_txt))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2020-01-22 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-01-23 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-01-24 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-01-25 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-01-26 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-01-27 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-01-28 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-01-29 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-01-30 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-01-31 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-01 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-02 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-03 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-04 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-05 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-06 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-07 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-08 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-09 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-10 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-11 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-12 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-13 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-14 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-15 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-16 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-17 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-18 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-19 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-20 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-21 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-22 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-23 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-24 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-25 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-26 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-27 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-28 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-02-29 | Province/State Country/Region Last Update Confirmed Deaths Recovered
# 2020-03-01 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-02 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-03 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-04 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-05 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-06 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-07 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-08 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-09 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-10 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-11 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-12 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-13 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-14 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-15 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-16 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-17 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-18 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-19 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-20 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-21 | Province/State Country/Region Last Update Confirmed Deaths Recovered Latitude Longitude
# 2020-03-22 | FIPS Admin2 Province_State Country_Region Last_Update Lat Long_ Confirmed Deaths Recovered Active Combined_Key
# 2020-03-23 | FIPS Admin2 Province_State Country_Region Last_Update Lat Long_ Confirmed Deaths Recovered Active Combined_Key
# 2020-03-24 | FIPS Admin2 Province_State Country_Region Last_Update Lat Long_ Confirmed Deaths Recovered Active Combined_Key
# 2020-03-25 | FIPS Admin2 Province_State Country_Region Last_Update Lat Long_ Confirmed Deaths Recovered Active Combined_Key
# 2020-03-26 | FIPS Admin2 Province_State Country_Region Last_Update Lat Long_ Confirmed Deaths Recovered Active Combined_Key
# 2020-03-27 | FIPS Admin2 Province_State Country_Region Last_Update Lat Long_ Confirmed Deaths Recovered Active Combined_Key
# 2020-03-28 | FIPS Admin2 Province_State Country_Region Last_Update Lat Long_ Confirmed Deaths Recovered Active Combined_Key
# 2020-03-29 | FIPS Admin2 Province_State Country_Region Last_Update Lat Long_ Confirmed Deaths Recovered Active Combined_Key
# 2020-03-30 | FIPS Admin2 Province_State Country_Region Last_Update Lat Long_ Confirmed Deaths Recovered Active Combined_Key
# 2020-03-31 | FIPS Admin2 Province_State Country_Region Last_Update Lat Long_ Confirmed Deaths Recovered Active Combined_Key
# 2020-04-01 | FIPS Admin2 Province_State Country_Region Last_Update Lat Long_ Confirmed Deaths Recovered Active Combined_Key
# 2020-04-02 | FIPS Admin2 Province_State Country_Region Last_Update Lat Long_ Confirmed Deaths Recovered Active Combined_Key
# 2020-04-03 | FIPS Admin2 Province_State Country_Region Last_Update Lat Long_ Confirmed Deaths Recovered Active Combined_Key
# 2020-04-04 | FIPS Admin2 Province_State Country_Region Last_Update Lat Long_ Confirmed Deaths Recovered Active Combined_Key
# 2020-04-05 | FIPS Admin2 Province_State Country_Region Last_Update Lat Long_ Confirmed Deaths Recovered Active Combined_Key
# 2020-04-06 | FIPS Admin2 Province_State Country_Region Last_Update Lat Long_ Confirmed Deaths Recovered Active Combined_Key
#   3200K .......... .......... .......... .......... .......... 91% 30.6M 0s
#   3250K .......... .......... .......... .......... .......... 92% 32.9M 0s
#   3300K .......... .......... .......... .......... .......... 94% 36.0M 0s
#   3350K .......... .......... .......... .......... .......... 95% 30.8M 0s
#   3400K .......... .......... .......... .......... .......... 96% 30.2M 0s
#   3450K .......... .......... .......... .......... .......... 98% 33.4M 0s
#   3500K .......... .......... .......... .......... .......... 99% 31.7M 0s
#   3550K .........                                             100% 18.3M=0.2s
#
# 2020-04-17 23:11:52 (22.3 MB/s) - ‘/dbfs/tmp/dennylee/COVID/population_estimates_by_county/co-est2019-alldata.csv’ saved [3644730/3644730]
#
# total 5307
# drwxrwxrwx 2 root root    4096 Apr 17  2020 .
# drwxrwxrwx 2 root root    4096 Apr 17 22:29 ..
# -rwxrwxrwx 1 root root 1781101 Apr 15 05:49 CO-EST2014-alldata.csv
# -rwxrwxrwx 1 root root 3644730 Apr 17  2020 co-est2019-alldata.csv
# </div>

# %%
map_popest_county = spark.read.option("header", True).option("inferSchema", True).csv("/tmp/dennylee/COVID/population_estimates_by_county/co-est2019-alldata.csv")
map_popest_county.createOrReplaceTempView("map_popest_county")
fips_popest_county = spark.sql("select State * 1000 + substring(cast(1000 + County as string), 2, 3) as fips, STNAME, CTYNAME, census2010pop, POPESTIMATE2019 from map_popest_county")
fips_popest_county.createOrReplaceTempView("fips_popest_county")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Include Population Estimates
# Create `jhu_daily_pop` to include population estimates; note, by including population estimates we're limiting our dataset from 3/22 onwards as the data prior to 3/22 does not contain `FIPS` information.

# %%
jhu_daily_pop = spark.sql("""
SELECT f.FIPS, f.Admin2, f.Province_State, f.Country_Region, f.Last_Update, f.Lat, f.Long_, f.Confirmed, f.Deaths, f.Recovered, f.Active, f.Combined_Key, f.process_date, p.POPESTIMATE2019 
  FROM jhu_daily f
    JOIN fips_popest_county p
      ON p.fips = f.FIPS
""")
jhu_daily_pop.createOrReplaceTempView("jhu_daily_pop")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Initial Exploratory Data Analysis

# %% [markdown]
# #### Reviewing the confirmed cases and deaths for NY and King Counties

# %%
# %sql
select process_date, Admin2, Confirmed, Deaths, Recovered, Active from jhu_daily where Province_State in ('New York') and Admin2 in ('New York City')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>process_date</th><th>Admin2</th><th>Confirmed</th><th>Deaths</th><th>Recovered</th><th>Active</th></tr></thead><tbody><tr><td>2020-03-22</td><td>New York City</td><td>9654</td><td>63</td><td>0</td><td>0</td></tr><tr><td>2020-03-23</td><td>New York City</td><td>12305</td><td>99</td><td>0</td><td>0</td></tr><tr><td>2020-03-24</td><td>New York City</td><td>14904</td><td>131</td><td>0</td><td>0</td></tr><tr><td>2020-03-25</td><td>New York City</td><td>17856</td><td>199</td><td>0</td><td>0</td></tr><tr><td>2020-03-26</td><td>New York City</td><td>21873</td><td>281</td><td>0</td><td>0</td></tr><tr><td>2020-03-27</td><td>New York City</td><td>25573</td><td>366</td><td>0</td><td>0</td></tr><tr><td>2020-03-28

# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def map_usa_cases(curr_date):
  # Obtain altair topographic information
  us_states = alt.topo_feature(topo_usa, 'states')
  us_counties = alt.topo_feature(topo_usa, 'counties')

  # state borders
  base_states = alt.Chart(us_states).mark_geoshape().encode(
    stroke=alt.value('lightgray'), fill=alt.value('white')
  ).properties(
    width=1200,
    height=960,
  ).project(
    type='albersUsa',
  )


  # confirmed cases by county
  base_counties = alt.Chart(us_counties).mark_geoshape().encode(
    color=alt.Color('confirmed:Q', scale=alt.Scale(type='log'), title='Confirmed'),
  ).transform_lookup(
    lookup='id',
    from_=alt.LookupData(pdf_usa[(pdf_usa['confirmed'] > 0) & (pdf_usa['process_date'] == curr_date)], 'fips', ['confirmed'])  
  )

  # deaths by long, latitude
  points = alt.Chart(pdf_usa[(pdf_usa['deaths'] > 0) & (pdf_usa['process_date'] == curr_date)]).mark_point(opacity=0.75, filled=True).encode(
    longitude='long_:Q',
    latitude='lat:Q',
    size=alt.Size('sum(deaths):Q', scale=alt.Scale(type='symlog'), title='deaths'),
    color=alt.value('#BD595D'),
    stroke=alt.value('brown'),
    tooltip=[
      alt.Tooltip('state', title='state'), 
      alt.Tooltip('county', title='county'), 
      alt.Tooltip('confirmed', title='confirmed'),
      alt.Tooltip('deaths', title='deaths'),       
    ],
  ).properties(
    # update figure title
    title=f'COVID-19 Confirmed Cases and Deaths by County {curr_date}'
  )

  # display graph
  return (base_states + base_counties + points)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def map_usa_cases(curr_date):
  # Obtain altair topographic information
  us_states = alt.topo_feature(topo_usa, 'states')
  us_counties = alt.topo_feature(topo_usa, 'counties')

  # state borders
  base_states = alt.Chart(us_states).mark_geoshape().encode(
    stroke=alt.value('lightgray'), fill=alt.value('white')
  ).properties(
    width=1200,
    height=960,
  ).project(
    type='albersUsa',
  )


  # confirmed cases by county
  base_counties = alt.Chart(us_counties).mark_geoshape().encode(
    color=alt.Color('confirmed_per100K:Q', scale=alt.Scale(domain=(1, 7500), type='log'), title='Confirmed per 100K'),
  ).transform_lookup(
    lookup='id',
    from_=alt.LookupData(pdf_usa[(pdf_usa['confirmed_per100K'] > 0) & (pdf_usa['process_date'] == curr_date)], 'fips', ['confirmed_per100K'])  
  )

  # deaths by long, latitude
  points = alt.Chart(pdf_usa[(pdf_usa['deaths_per100K'] > 0) & (pdf_usa['process_date'] == curr_date)]).mark_point(opacity=0.75, filled=True).encode(
    longitude='long_:Q',
    latitude='lat:Q',
     size=alt.Size('deaths_per100K:Q', scale=alt.Scale(domain=(1, 1000), type='log'), title='deaths_per100K'),
     #size=alt.Size('deaths_per100K:Q', title='deaths_per100K'),
     color=alt.value('#BD595D'),
     stroke=alt.value('brown'),
    tooltip=[
      alt.Tooltip('state', title='state'), 
      alt.Tooltip('county', title='county'), 
      alt.Tooltip('confirmed_per100K', title='confirmed'),
      alt.Tooltip('deaths_per100K', title='deaths'),       
    ],
  ).properties(
    # update figure title
    title=f'COVID-19 Confirmed Cases and Deaths by County (by 100K) {curr_date}'
  )

   # display graph
  return (base_states + base_counties + points)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Starting Date (2020-03-22)
map_usa_cases('2020-03-22')
# Out:
# <div id="altair-viz-09b84d9faf834ddd8cba319b8198dbb0"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-09b84d9faf834ddd8cba319b8198dbb0") {
#       outputDiv = document.getElementById("altair-viz-09b84d9faf834ddd8cba319b8198dbb0");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "states", "type": "topojson"}}, "mark": "geoshape", "encoding": {"fill": {"value": "white"}, "stroke": {"value": "lightgray"}}, "height": 960, "projection": {"type": "albersUsa"}, "width": 1200}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": "geoshape", "encoding": {"color": {"type": "quantitative", "field": "confirmed_per100K", "scale": {"domain": [1, 7500], "type": "log"}, "title": "Confirmed per 100K"}}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-91b9c0cc3832075712d780accd0e755e"}, "key": "fips", "fields": ["confirmed_per100K"]}}]}, {"data": {"name": "data-6979b8b5e6ce6dca1cd843c164edc5db"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "field": "deaths_per100K", "scale": {"domain": [1, 1000], "type": "log"}, "title": "deaths_per100K"}, "stroke": {"value": "brown"}, "tooltip": [{"type": "nominal", "field": "state", "title": "state"}, {"type": "nominal", "field": "county", "title": "county"}, {"type": "quantitative", "field": "confirmed_per100K", "title": "confirmed"}, {"type": "quantitative", "field": "deaths_per100K", "title": "deaths"}]}, "title": "COVID-19 Confirmed Cases and Deaths by County (by 100K) 2020-03-22"}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-91b9c0cc3832075712d780accd0e755e": [{"fips": 36061, "confirmed_per100K": 592, "deaths_per100K": 3, "recovered": 0, "active": 0, "lat": 40.7672726, "long_": -73.97152637, "county": "New York City", "state": "New York", "process_date": "2020-03-22", "process_date_num": 20200322}, {"fips": 36059, "confirmed_per100K": 140, "deaths_per100K": 0, "recovered": 0, "active": 0, "lat": 40.74066522, "long_": -73.58941873, "county": "Nassau", "state": "New York", "process_date": "2020-03-22", "process_date_num": 20200322}, {"fips": 36119, "confirmed_per100K": 193, "deaths_per100K": 0, "recovered": 0, "active": 0, "lat": 41.16278376, "long_": -73.75741653, "county": "Westchester", "state": "New York", "process_date": "2020-03-22", "process_date_num": 20200322}, {"fips": 36103, "confirmed_per100K": 70, "deaths_per100K": 0, "recovered": 0, "active": 0, "lat": 40.88320119, "long_": -72.8012172, "county": "Suffolk", "state": "New York", "process_date": "2020-03-22", "process_date_num": 20200322}, {"fips": 36087, "confirmed_per100K": 139, "deaths_per100K": 0, "recovered": 0, "active": 0, "lat": 41.15027894, "long_": -74.02560498, "county": "Rockland", "state": "New York", "process_date": "2020-03-22", "process_date_num": 20200322}, {"fips": 36071, "confirmed_per100K": 64, "deaths_per100K": 0, "recovered": 0, "active": 0, "lat": 41.40337468, "long_": -74.30240757, "county": "Orange", "state": "New York", "process_date": "2020-03-22", "process_date_num": 20200322}, {"fips": 36001, "confirmed_per100K": 40, "deaths_per100K": 0, "recovered": 0, "active": 0, "lat": 42.60060306, "long_": -73.97723916, "county": "Albany", "state": "New York", "process_date": "2020-03-22", "process_date_num": 20200322}, {"fips": 36027, "confirmed_per100K": 27, "deaths_per100K": 0, "recovered": 0, "active": 0, "lat": 41.7648606, "long_": -73.74356679, "county": "Dutchess", "state": "New York", "process_date": "2020-03-22", "process_date_num": 20200322}, {"fips": 36055, "confirmed_per100K": 9, "deaths_per100K": 0, "recovered": 0, "active": 0, "lat": 43.14638895, "long_": -77.69322942, "county": "Monroe", "state": "New York", "process_date": "2020-03-22", "process_date_num": 20200322}, {"fips": 36029, "confirmed_per100K": 6, "deaths_per100K": 0, "recovered": 0, "active": 0, "lat": 42. ...

# %%
# Latest Date (2020-04-14)
map_usa_cases('2020-04-14')
# Out:
# <div id="altair-viz-ef7b3adb0511412d95eebea4c27d3a4e"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-ef7b3adb0511412d95eebea4c27d3a4e") {
#       outputDiv = document.getElementById("altair-viz-ef7b3adb0511412d95eebea4c27d3a4e");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "states", "type": "topojson"}}, "mark": "geoshape", "encoding": {"fill": {"value": "white"}, "stroke": {"value": "lightgray"}}, "height": 960, "projection": {"type": "albersUsa"}, "width": 1200}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": "geoshape", "encoding": {"color": {"type": "quantitative", "field": "confirmed_per100K", "scale": {"domain": [1, 7500], "type": "log"}, "title": "Confirmed per 100K"}}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-3da3a89983393ef3695181ab21e4449d"}, "key": "fips", "fields": ["confirmed_per100K"]}}]}, {"data": {"name": "data-a4edfe61eeb4011a8633fa4be8c11378"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "field": "deaths_per100K", "scale": {"domain": [1, 1000], "type": "log"}, "title": "deaths_per100K"}, "stroke": {"value": "brown"}, "tooltip": [{"type": "nominal", "field": "state", "title": "state"}, {"type": "nominal", "field": "county", "title": "county"}, {"type": "quantitative", "field": "confirmed_per100K", "title": "confirmed"}, {"type": "quantitative", "field": "deaths_per100K", "title": "deaths"}]}, "title": "COVID-19 Confirmed Cases and Deaths by County (by 100K) 2020-04-14"}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-3da3a89983393ef3695181ab21e4449d": [{"fips": 45001, "confirmed_per100K": 36, "deaths_per100K": 0, "recovered": 0, "active": 9, "lat": 34.22333378, "long_": -82.46170658, "county": "Abbeville", "state": "South Carolina", "process_date": "2020-04-14", "process_date_num": 20200414}, {"fips": 22001, "confirmed_per100K": 167, "deaths_per100K": 8, "recovered": 0, "active": 99, "lat": 30.295064899999996, "long_": -92.41419698, "county": "Acadia", "state": "Louisiana", "process_date": "2020-04-14", "process_date_num": 20200414}, {"fips": 51001, "confirmed_per100K": 46, "deaths_per100K": 0, "recovered": 0, "active": 15, "lat": 37.76707161, "long_": -75.63234615, "county": "Accomack", "state": "Virginia", "process_date": "2020-04-14", "process_date_num": 20200414}, {"fips": 16001, "confirmed_per100K": 111, "deaths_per100K": 1, "recovered": 0, "active": 529, "lat": 43.4526575, "long_": -116.24155159999998, "county": "Ada", "state": "Idaho", "process_date": "2020-04-14", "process_date_num": 20200414}, {"fips": 19001, "confirmed_per100K": 13, "deaths_per100K": 0, "recovered": 0, "active": 1, "lat": 41.33075609, "long_": -94.47105874, "county": "Adair", "state": "Iowa", "process_date": "2020-04-14", "process_date_num": 20200414}, {"fips": 21001, "confirmed_per100K": 223, "deaths_per100K": 5, "recovered": 0, "active": 42, "lat": 37.10459774, "long_": -85.28129668, "county": "Adair", "state": "Kentucky", "process_date": "2020-04-14", "process_date_num": 20200414}, {"fips": 29001, "confirmed_per100K": 47, "deaths_per100K": 0, "recovered": 0, "active": 12, "lat": 40.19058551, "long_": -92.60078167, "county": "Adair", "state": "Missouri", "process_date": "2020-04-14", "process_date_num": 20200414}, {"fips": 40001, "confirmed_per100K": 126, "deaths_per100K": 9, "recovered": 0, "active": 26, "lat": 35.88494195, "long_": -94.65859267, "county": "Adair", "state": "Oklahoma", "process_date": "2020-04-14", "process_date_num": 20200414}, {"fips": 8001, "confirmed_per100K": 140, "deaths_per100K": 5, "recovered": 0, "active": 699, "lat": 39.87432092, "long_": -104.3362578, "county": "Adams", "state": "Colorado", "process_date": "2020-04-14", "process_date_num": 20200414}, {"fips": 16003, "confirmed_per100K": 23, "deaths_per100K": 0, "recovered": 0, "active": 1, "la ...

# %% [markdown]
# ## COVID-19 Confirmed Cases and Deaths by County Slider

# %%
# Create `usa_confirmed` dataframe 
process_date_zero = spark.sql("select min(process_date) from df_usa where fips is not null").collect()[0][0]
df_usa_conf = spark.sql("""
select fips, 100 + datediff(process_date, '""" + process_date_zero + """') as day_num, confirmed_per100K
  from (
     select fips, process_date, max(confirmed_per100K) as confirmed_per100K
       from df_usa
      group by fips, process_date
) x """)
df_usa_conf.createOrReplaceTempView("df_usa_conf")

# Convert to Pandas
pdf_usa_conf = df_usa_conf.toPandas()
pdf_usa_conf['day_num'] = pdf_usa_conf['day_num'].astype(str)
pdf_usa_conf['confirmed_per100K'] = pdf_usa_conf['confirmed_per100K'].astype('int64')
pdf_usa_conf = pdf_usa_conf.pivot_table(index='fips', columns='day_num', values='confirmed_per100K', fill_value=0).reset_index()

# Create `usa_deaths` datasframe
df_usa_deaths = spark.sql("""
select lat, long_, 100 + datediff(process_date, '""" + process_date_zero + """') as day_num, deaths_per100K
  from (
     select lat, long_, process_date, max(deaths_per100K) as deaths_per100K
       from df_usa
      group by lat, long_, process_date
) x """)
df_usa_deaths.createOrReplaceTempView("df_usa_deaths")

# Covnert to pandas
pdf_usa_deaths = df_usa_deaths.toPandas()
pdf_usa_deaths['day_num'] = pdf_usa_deaths['day_num'].astype(str)
pdf_usa_deaths['deaths_per100K'] = pdf_usa_deaths['deaths_per100K'].astype('int64')
pdf_usa_deaths = pdf_usa_deaths.pivot_table(index=['lat', 'long_'], columns='day_num', values='deaths_per100K', fill_value=0).reset_index()

# Extract column names for slider
column_names = pdf_usa_conf.columns.tolist()

# Remove first element (`fips`)
column_names.pop(0)

# Convert to int
column_values = [None] * len(column_names)
for i in range(0, len(column_names)): column_values[i] = int(column_names[i])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Disable max_rows to see more data
alt.data_transformers.disable_max_rows()

# Topographic information
us_states = alt.topo_feature(topo_usa, 'states')
us_counties = alt.topo_feature(topo_usa, 'counties')

# state borders
base_states = alt.Chart(us_states).mark_geoshape().encode(
  stroke=alt.value('lightgray'), fill=alt.value('white')
).properties(
  width=1200,
  height=960,
).project(
  type='albersUsa',
)

# Slider choices
min_day_num = column_values[0]
max_day_num = column_values[len(column_values)-1]
slider = alt.binding_range(min=min_day_num, max=max_day_num, step=1)
slider_selection = alt.selection_single(fields=['day_num'], bind=slider, name="day_num", init={'day_num':max_day_num})

# Confirmed cases by county
base_counties = alt.Chart(us_counties).mark_geoshape(
    stroke='black',
    strokeWidth=0.05
).project(
    type='albersUsa'
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(pdf_usa_conf, 'fips', column_names)  
).transform_fold(
    column_names, as_=['day_num', 'confirmed_per100K']
).transform_calculate(
    day_num = 'parseInt(datum.day_num)',
    confirmed_per100K = 'isValid(datum.confirmed_per100K) ? datum.confirmed_per100K : -1'
).encode(
    color = alt.condition(
        'datum.confirmed_per100K > 0',      
        alt.Color('confirmed_per100K:Q', scale=alt.Scale(domain=(1, 7500), type='log')),
        alt.value('white')
      )  
).transform_filter(
    slider_selection
# ).add_selection(
#     slider_selection
)

# deaths by long, latitude
points = alt.Chart(
  pdf_usa_deaths
).mark_point(
  opacity=0.75, filled=True
).transform_fold(
  column_names, as_=['day_num', 'deaths_per100K']
).transform_calculate(
    day_num = 'parseInt(datum.day_num)',
    deaths_per100K = 'isValid(datum.deaths_per100K) ? datum.deaths_per100K : -1'  
).encode(
  longitude='long_:Q',
  latitude='lat:Q',
  size=alt.Size('deaths_per100K:Q', scale=alt.Scale(domain=(1, 1000), type='log'), title='deaths_per100K'),
  color=alt.value('#BD595D'),
  stroke=alt.value('brown'),
).properties(
  # update figure title
  title=f'COVID-19 Confirmed Cases and Deaths by County (per 100K) Between 3/22 to 4/14 (2020)'
).add_selection(
    slider_selection
).transform_filter(
    slider_selection
)

# confirmed cases (base_counties) and deaths (points)
(base_states + base_counties + points)
# Out:
# <div id="altair-viz-9abeb462f7b84175a98d0c4932af1434"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-9abeb462f7b84175a98d0c4932af1434") {
#       outputDiv = document.getElementById("altair-viz-9abeb462f7b84175a98d0c4932af1434");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "states", "type": "topojson"}}, "mark": "geoshape", "encoding": {"fill": {"value": "white"}, "stroke": {"value": "lightgray"}}, "height": 960, "projection": {"type": "albersUsa"}, "width": 1200}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": {"type": "geoshape", "stroke": "black", "strokeWidth": 0.05}, "encoding": {"color": {"condition": {"type": "quantitative", "field": "confirmed_per100K", "scale": {"domain": [1, 7500], "type": "log"}, "test": "datum.confirmed_per100K > 0"}, "value": "white"}}, "projection": {"type": "albersUsa"}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-486a0396f04971595c7130cf62a455e9"}, "key": "fips", "fields": ["100", "101", "102", "103", "104", "105", "106", "107", "108", "109", "110", "111", "112", "113", "114", "115", "116", "117", "118", "119", "120", "121", "122", "123", "124"]}}, {"fold": ["100", "101", "102", "103", "104", "105", "106", "107", "108", "109", "110", "111", "112", "113", "114", "115", "116", "117", "118", "119", "120", "121", "122", "123", "124"], "as": ["day_num", "confirmed_per100K"]}, {"calculate": "parseInt(datum.day_num)", "as": "day_num"}, {"calculate": "isValid(datum.confirmed_per100K) ? datum.confirmed_per100K : -1", "as": "confirmed_per100K"}, {"filter": {"selection": "day_num"}}]}, {"data": {"name": "data-e2dcfcb05db76b841811ef8fa69d324b"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "field": "deaths_per100K", "scale": {"domain": [1, 1000], "type": "log"}, "title": "deaths_per100K"}, "stroke": {"value": "brown"}}, "selection": {"day_num": {"type": "single", "fields": ["day_num"], "bind": {"input": "range", "max": 124, "min": 100, "step": 1}, "init": {"day_num": 124}}}, "title": "COVID-19 Confirmed Cases and Deaths by County (per 100K) Between 3/22 to 4/14 (2020)", "transform": [{"fold": ["100", "101", "102", "103", "104", "105", "106", "107", "108", "109", "110", "111", "112", "113", "114", "115", "116", "117", "118", "119", "120", "121", "122", "123", "124"], "as": ["day_num", "deaths_per100K"]}, {"calculate": "parseInt(datum.day_num)", "as": "day_num"}, {"calculate": "isValid(datum.deaths_per100K) ? datum.deaths_per100K : -1", "as": "deaths_per100K"}, {"filter": {"selection": "day_num"}}]}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-486a0396f04971595c7130cf62a455e9": [{"fips": 1001, "100": 0, "101": 0, "102": 1, "103": 7, "104": 10, "105": 10, "106": 10, "107": 10, "108": 10, "109": 12, "110": 14, "111": 17, "112": 21, "113": 21, "114": 21, "115": 21, "116": 21, "117": 21, "118": 26, "119": 30, "120": 34, "121": 34, "122": 34, "123": 41, "124": 42}, {"fips": 1003, "100": 0, "101": 1, "102": 1, "103": 1, "104": 2, "105": 2, "106": 4, "107": 6, "108": 8, "109": 8, "110": 8, "111": 10, "112": 12, "113": 12, "114": 12, "115": 17, "116": 18, "117": 19, "118": 25, "119": 26, "120": 29, "121": 31, "122": 32, "123": 38, "124": 40}, {"fips": 1005, "100": 0, "101": 0, "102": 0, "103": 0, "104": 0, "105": 0, "106": 0, "107": 0, "108": 0, "109": 0, "110": 0, "111": 0, "112": 4, "113": 8, "114": 8, "115": 8, "116": 12, "117": 12, "118": 16, "119": 36, "120": 36, "121": 40, "122": 40, "123": 44, "124": 48}, {"fips": 1007, "100": 0, "101": 0, "102": 0, "103": 0, "104": 0, "105": 0, "106": 0, "107": 0, "108": 8, "109": 13, "110": 13, "111": 17, "112": 17, "113": 17, "114": 22, "115": 31, "116": 35, "117": 40, "118": 40, "119": 49, "120": 58, "121": 71, "122": 75, "123": 75, "124": 80}, {"fips": 1009, "100": 0, "101": 0, "102": 0, "103": 1, "104": 3, "105 ...
