# %% [markdown]
# ## NYT COVID-19 Analysis
# This notebook processes and performs quick analysis from the [New York Times COVID-19 dataset](https://github.com/nytimes/covid-19-data).  The data is updated in the `/databricks-datasets/COVID/covid-19-data/` location regularly so you can access the data directly.

# %%
# Standard Libraries
import io

# External Libraries
import requests
import numpy as np
import pandas as pd
import altair as alt
from vega_datasets import data

# topographical
topo_usa = 'https://vega.github.io/vega-datasets/data/us-10m.json'
topo_wa = 'https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/WA-53-washington-counties.json'
topo_king = 'https://raw.githubusercontent.com/johan/world.geo.json/master/countries/USA/WA/King.geo.json'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Download Mapping County FIPS to lat, long_

# %%
# %sh mkdir -p /dbfs/tmp/dennylee/COVID/map_fips/ && wget -O /dbfs/tmp/dennylee/COVID/map_fips/countyfips_lat_long.csv https://raw.githubusercontent.com/dennyglee/tech-talks/master/datasets/countyfips_lat_long.csv && ls -al /dbfs/tmp/dennylee/COVID/map_fips/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">--2020-04-13 23:01:06--  https://raw.githubusercontent.com/dennyglee/tech-talks/master/datasets/countyfips_lat_long.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.52.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.52.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 129178 (126K) [text/plain]
# Saving to: ‘/dbfs/tmp/dennylee/COVID/map_fips/countyfips_lat_long.csv’
#
#      0K .......... .......... .......... .......... .......... 39% 2.22M 0s
#     50K .......... .......... .......... .......... .......... 79% 5.31M 0s
#    100K .......... .......... ......                          100% 11.8M=0.03s
#
# 2020-04-13 23:01:06 (3.69 MB/s) - ‘/dbfs/tmp/dennylee/COVID/map_fips/countyfips_lat_long.csv’ saved [129178/129178]
#
# total 135
# drwxrwxrwx 2 root root   4096 Apr 13  2020 .
# drwxrwxrwx 2 root root   4096 Apr 13 21:13 ..
# -rwxrwxrwx 1 root root 129178 Apr 13  2020 countyfips_lat_long.csv
# </div>

# %%
# Create mapping of county FIPS to centroid long_ and lat
map_fips = spark.read.option("header", True).option("inferSchema", True).csv("/tmp/dennylee/COVID/map_fips/countyfips_lat_long.csv")
map_fips = (map_fips
              .withColumnRenamed("STATE", "state")
              .withColumnRenamed("COUNTYNAME", "county")
              .withColumnRenamed("LAT", "lat")
              .withColumnRenamed("LON", "long_"))
map_fips.createOrReplaceTempView("map_fips")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
map_fips_dedup = spark.sql("""select fips, min(state) as state, min(county) as county, min(long_) as long_, min(lat) as lat from map_fips group by fips""")
map_fips_dedup.createOrReplaceTempView("map_fips_dedup")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Download 2014 Population Estimates

# %%
# %sh mkdir -p /dbfs/tmp/dennylee/COVID/population_estimates_by_county/ && wget -O /dbfs/tmp/dennylee/COVID/population_estimates_by_county/CO-EST2014-alldata.csv https://raw.githubusercontent.com/dennyglee/tech-talks/master/datasets/county-estimates.csv && ls -al /dbfs/tmp/dennylee/COVID/population_estimates_by_county/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">--2020-04-14 01:21:55--  https://raw.githubusercontent.com/dennyglee/tech-talks/master/datasets/county-estimates.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.52.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.52.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1781101 (1.7M) [text/plain]
# Saving to: ‘/dbfs/tmp/dennylee/COVID/population_estimates_by_county/CO-EST2014-alldata.csv’
#
#      0K .......... .......... .......... .......... ..........  2% 3.52M 0s
#     50K .......... .......... .......... .......... ..........  5% 8.06M 0s
#    100K .......... .......... .......... .......... ..........  8% 25.9M 0s
#    150K .......... .......... .......... .......... .......... 11% 11.8M 0s
#    200K .......... .......... .......... .......... .......... 14% 29.7M 0s
#    250K .......... .......... .......... .......... .......... 17% 29.4M 0s
#    300K .......... .......... .......... .......... .......... 20% 31.0M 0s
#    350K .......... .......... .......... .......... .......... 22% 18.3M 0s
#    400K .......... .......... .......... .......... .......... 25% 26.5M 0s
#    450K .......... .......... .......... .......... .......... 28% 29.6M 0s
#    500K .......... .......... .......... .......... .......... 31% 31.2M 0s
#    550K .......... .......... .......... .......... .......... 34% 25.4M 0s
#    600K .......... .......... .......... .......... .......... 37% 28.0M 0s
#    650K .......... .......... .......... .......... .......... 40% 30.6M 0s
#    700K .......... .......... .......... .......... .......... 43% 30.5M 0s
#    750K .......... .......... .......... .......... .......... 45% 21.4M 0s
#    800K .......... .......... .......... .......... .......... 48% 29.5M 0s
#    850K .......... .......... .......... .......... .......... 51% 30.7M 0s
#    900K .......... .......... .......... .......... .......... 54% 26.9M 0s
#    950K .......... .......... .......... .......... .......... 57% 25.9M 0s
#   1000K .......... .......... .......... .......... .......... 60% 28.0M 0s
#   1050K .......... .......... .......... .......... .......... 63% 30.7M 0s
#   1100K .......... .......... .......... .......... .......... 66% 31.6M 0s
#   1150K .......... .......... .......... .......... .......... 68% 24.8M 0s
#   1200K .......... .......... .......... .......... .......... 71% 30.1M 0s
#   1250K .......... .......... .......... .......... .......... 74% 29.9M 0s
#   1300K .......... .......... .......... .......... .......... 77% 31.0M 0s
#   1350K .......... .......... .......... .......... .......... 80% 24.7M 0s
#   1400K .......... .......... .......... .......... .......... 83% 29.3M 0s
#   1450K .......... .......... .......... .......... .......... 86% 28.6M 0s
#   1500K .......... .......... .......... .......... .......... 89% 30.8M 0s
#   1550K .......... .......... .......... .......... .......... 91% 26.3M 0s
#   1600K .......... .......... .......... .......... .......... 94% 32.1M 0s
#   1650K .......... .......... .......... .......... .......... 97% 31.8M 0s
#   1700K .......... .......... .......... .........            100% 30.5M=0.08s
#
# 2020-04-14 01:21:55 (21.4 MB/s) - ‘/dbfs/tmp/dennylee/COVID/population_estimates_by_county/CO-EST2014-alldata.csv’ saved [1781101/1781101]
#
# total 1748
# drwxrwxrwx 2 root root    4096 Apr 14  2020 .
# drwxrwxrwx 2 root root    4096 Apr 14 01:17 ..
# -rwxrwxrwx 1 root root 1781101 Apr 14  2020 CO-EST2014-alldata.csv
# </div>

# %%
map_popest_county = spark.read.option("header", True).option("inferSchema", True).csv("/tmp/dennylee/COVID/population_estimates_by_county/CO-EST2014-alldata.csv")
map_popest_county.createOrReplaceTempView("map_popest_county")
fips_popest_county = spark.sql("select State * 1000 + substring(cast(1000 + County as string), 2, 3) as fips, STNAME, CTYNAME, census2010pop, POPESTIMATE2014 from map_popest_county")
fips_popest_county.createOrReplaceTempView("fips_popest_county")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Specify `nyt_daily` table
# * Source: `/databricks-datasets/COVID/covid-19-data/`
# * Contains the COVID-19 daily reports

# %%
nyt_daily = spark.read.option("inferSchema", True).option("header", True).csv("/databricks-datasets/COVID/covid-19-data/us-counties.csv")
nyt_daily.createOrReplaceTempView("nyt_daily")
display(nyt_daily)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>county</th><th>state</th><th>fips</th><th>cases</th><th>deaths</th></tr></thead><tbody><tr><td>2020-01-21T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-22T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-23T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-24T00:00:00.000+0000</td><td>Cook</td><td>Illinois</td><td>17031</td><td>1</td><td>0</td></tr><tr><td>2020-01-24T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-25T00:00:00.000+0000</td><td>Orange</td><td>California</td><td>6059</td><td>1</td><td>0</td></tr><tr><td>2020-01-25T00:00:00.000+0000</td><td>Cook</td><td>Illinois</td><td>17031</td><td>1</td><td>0</td></tr><tr><td>2020-01-25T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-26T00:00:00.000+0000</td><td>Maricopa</td><td>Arizona</td><td>4013</td><td>1</td><td>0</td></tr><tr><td>2020-01-26T00:00:00.000+0000</td><td>Los Angeles</td><td>California</td><td>6037</td><td>1</td><td>0</td></tr><tr><td>2020-01-26T00:00:00.000+0000</td><td>Orange</td><td>California</td><td>6059</td><td>1</td><td>0</td></tr><tr><td>2020-01-26T00:00:00.000+0000</td><td>Cook</td><td>Illinois</td><td>17031</td><td>1</td><td>0</td></tr><tr><td>2020-01-26T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-27T00:00:00.000+0000</td><td>Maricopa</td><td>Arizona</td><td>4013</td><td>1</td><td>0</td></tr><tr><td>2020-01-27T00:00:00.000+0000</td><td>Los Angeles</td><td>California</td><td>6037</td><td>1</td><td>0</td></tr><tr><td>2020-01-27T00:00:00.000+0000</td><td>Orange</td><td>California</td><td>6059</td><td>1</td><td>0</td></tr><tr><td>2020-01-27T00:00:00.000+0000</td><td>Cook</td><td>Illinois</td><td>17031</td><td>1</td><td>0</td></tr><tr><td>2020-01-27T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-28T00:00:00.000+0000</td><td>Maricopa</td><td>Arizona</td><td>4013</td><td>1</td><td>0</td></tr><tr><td>2020-01-28T00:00:00.000+0000</td><td>Los Angeles</td><td>California</td><td>6037</td><td>1</td><td>0</td></tr><tr><td>2020-01-28T00:00:00.000+0000</td><td>Orange</td><td>California</td><td>6059</td><td>1</td><td>0</td></tr><tr><td>2020-01-28T00:00:00.000+0000</td><td>Cook</td><td>Illinois</td><td>17031</td><td>1</td><td>0</td></tr><tr><td>2020-01-28T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-29T00:00:00.000+0000</td><td>Maricopa</td><td>Arizona</td><td>4013</td><td>1</td><td>0</td></tr><tr><td>2020-01-29T00:00:00.000+0000</td><td>Los Angeles</td><td>California</td><td>6037</td><td>1</td><td>0</td></tr><tr><td>2020-01-29T00:00:00.000+0000</td><td>Orange</td><td>California</td><td>6059</td><td>1</td><td>0</td></tr><tr><td>2020-01-29T00:00:00.000+0000</td><td>Cook</td><td>Illinois</td><td>17031</td><td>1</td><td>0</td></tr><tr><td>2020-01-29T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-30T00:00:00.000+0000</td><td>Maricopa</td><td>Arizona</td><td>4013</td><td>1</td><td>0</td></tr><tr><td>2020-01-30T00:00:00.000+0000</td><td>Los Angeles</td><td>California</td><td>6037</td><td>1</td><td>0</td></tr><tr><td>2020-01-30T00:00:00.000+0000</td><td>Orange</td><td>California</td><td>6059</td><td>1</td><td>0</td></tr><tr><td>2020-01-30T00:00:00.000+0000</td><td>Cook</td><td>Illinois</td><td>17031</td><td>2</td><td>0</td></tr><tr><td>2020-01-30T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020- ...

# %% [markdown]
# # COVID-19 Cases and Deaths for Specific Counties
# Focusing on two-week window around when educational facilites were closed
# * Top 10 Washington State counties (3/13/2020)
# * Top 10 NY State counties (3/18/2020)

# %%
# WA State 2 week window
wa_state_window = spark.sql("""
SELECT date, 100 + datediff(date, '2020-03-06T00:00:00.000+0000') as day_num, county, fips, cases, deaths, 100000.*cases/population_estimate AS cases_per_100Kpop, 100000.*deaths/population_estimate AS deaths_per_100Kpop
  from (
SELECT CAST(f.date AS date) AS date, f.county, f.fips, SUM(f.cases) AS cases, SUM(f.deaths) AS deaths, MAX(p.POPESTIMATE2014) AS population_estimate 
  FROM nyt_daily f 
    JOIN fips_popest_county p
      ON p.fips = f.fips
 WHERE f.state = 'Washington' 
   AND date BETWEEN '2020-03-06T00:00:00.000+0000' AND '2020-03-20T00:00:00.000+0000'
 GROUP BY f.date, f.county, f.fips
) a""")
wa_state_window.createOrReplaceTempView("wa_state_window")

# NY State 2 week window
ny_state_window = spark.sql("""
SELECT date, 100 + datediff(date, '2020-03-11T00:00:00.000+0000') as day_num, county, fips, cases, deaths, 100000.*cases/population_estimate AS cases_per_100Kpop, 100000.*deaths/population_estimate AS deaths_per_100Kpop
  FROM (
SELECT CAST(f.date AS date) AS date, f.county, p.fips, SUM(f.cases) as cases, SUM(f.deaths) as deaths, MAX(p.POPESTIMATE2014) AS population_estimate  
  FROM nyt_daily f 
    JOIN fips_popest_county p
      ON p.fips = coalesce(f.fips, 36061)
 WHERE f.state = 'New York' 
   AND date BETWEEN '2020-03-11T00:00:00.000+0000' AND '2020-03-25T00:00:00.000+0000'
 GROUP BY f.date, f.county, p.fips
) a""")
wa_daynum.createOrReplaceTempView("wa_daynum")
ny_daynum = spark.sql("""select cast(f.fips as int) as fips, f.county, f.day_num, cast(f.cases_per_100Kpop as int) as confirmed, cast(f.deaths_per_100Kpop as int) as deaths, m.lat, m.long_ from ny_state_window f join map_fips_dedup m on m.fips = f.fips""")
ny_daynum.createOrReplaceTempView("ny_daynum")
ny_daynum_m1 = spark.sql("""select cast(f.fips as int) as fips, f.county, f.day_num, cast(f.cases_per_100Kpop as int) as confirmed, cast(f.deaths_per_100Kpop as int) as deaths, m.lat, m.long_ from ny_state_window_m1 f join map_fips_dedup m on m.fips = f.fips""")
ny_daynum_m1.createOrReplaceTempView("ny_daynum_m1")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Obtain Topography
topo_usa = 'https://vega.github.io/vega-datasets/data/us-10m.json'
topo_wa = 'https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/WA-53-washington-counties.json'
topo_ny = 'https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/NY-36-new-york-counties.json'
us_counties = alt.topo_feature(topo_usa, 'counties')
wa_counties = alt.topo_feature(topo_wa, 'cb_2015_washington_county_20m')
ny_counties = alt.topo_feature(topo_ny, 'cb_2015_new_york_county_20m')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Review WA
confirmed_wa = wa_daynum.select("fips", "day_num", "confirmed", "county").where("confirmed > 0").toPandas()
deaths_wa = wa_daynum.select("lat", "long_", "day_num", "deaths", "county").where("deaths > 0").toPandas()

# Review NY
confirmed_ny = ny_daynum.select("fips", "day_num", "confirmed", "county").where("confirmed > 0").toPandas()
deaths_ny = ny_daynum.select("lat", "long_", "day_num", "deaths", "county").where("deaths > 0").toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# State Choropleth Map Visualization Function
def map_state(curr_day_num, state_txt, state_counties, confirmed, confirmed_min, confirmed_max, deaths, deaths_min, deaths_max):
  # Washington State
  base_state = alt.Chart(state_counties).mark_geoshape(
      fill='white',
      stroke='lightgray',
  ).properties(
      width=1000,
      height=800,
  ).project(
      type='mercator'
  )

  # counties
  base_state_counties = alt.Chart(us_counties).mark_geoshape(
  ).transform_lookup(
    lookup='id',
    from_=alt.LookupData(confirmed[(confirmed['confirmed'] > 0) & (confirmed['day_num'] == curr_day_num)], 'fips', ['confirmed', 'county'])  
  ).encode(
     color=alt.Color('confirmed:Q', scale=alt.Scale(type='log', domain=[confirmed_min, confirmed_max]), title='Confirmed'),
    tooltip=[
      alt.Tooltip('confirmed:Q'),
      alt.Tooltip('county:O'),
    ],
  )

  # deaths by long, latitude
  points = alt.Chart(deaths[(deaths['deaths'] > 0) & (deaths['day_num'] == curr_day_num)]).mark_point(opacity=0.75, filled=True).encode(
    longitude='long_:Q',
    latitude='lat:Q',
    size=alt.Size('sum(deaths):Q', scale=alt.Scale(type='symlog', domain=[deaths_min, deaths_max]), title='deaths'),
    color=alt.value('#BD595D'),
    stroke=alt.value('brown'),
    tooltip=[
      alt.Tooltip('lat'),
      alt.Tooltip('long_'),
      alt.Tooltip('deaths'),
      alt.Tooltip('county:O'),      
    ],
  ).properties(
    # update figure title
    title=f'COVID-19 {state_txt} Confirmed Cases and Deaths per 100K by County [{curr_day_num}]'
  )

  return (base_state + base_state_counties + points)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# | Factors | WA | NY |
# | ------- | -- | -- |
# | Educational Facilities Closed | 3/13/2020 | 3/18/2020 |
# | Day 00 | 3/6/2020 | 3/11/2020 |
# | Day 14 | 3/20/2020 | 3/25/2020 |
# | Max Cases | 50.55 | 1222.97 |
# | Max Deaths | 3.27 | 17.11 |

# %% [markdown]
# ### WA State

# %%
map_state(101, 'WA', wa_counties, confirmed_wa, 1, 60, deaths_wa, 1, 5)
# Out:
# <div id="altair-viz-0f1797a3fa5547bead6a4d0d47b6c173"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-0f1797a3fa5547bead6a4d0d47b6c173") {
#       outputDiv = document.getElementById("altair-viz-0f1797a3fa5547bead6a4d0d47b6c173");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/WA-53-washington-counties.json", "format": {"feature": "cb_2015_washington_county_20m", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "white", "stroke": "lightgray"}, "height": 800, "projection": {"type": "mercator"}, "width": 1000}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": "geoshape", "encoding": {"color": {"type": "quantitative", "field": "confirmed", "scale": {"domain": [1, 60], "type": "log"}, "title": "Confirmed"}, "tooltip": [{"type": "quantitative", "field": "confirmed"}, {"type": "ordinal", "field": "county"}]}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-b0b5bbc5424a0c779187630e681c4477"}, "key": "fips", "fields": ["confirmed", "county"]}}]}, {"data": {"name": "data-d751713988987e9331980363e24189ce"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "aggregate": "sum", "field": "deaths", "scale": {"domain": [1, 5], "type": "symlog"}, "title": "deaths"}, "stroke": {"value": "brown"}, "tooltip": [{"type": "quantitative", "field": "lat"}, {"type": "quantitative", "field": "long_"}, {"type": "quantitative", "field": "deaths"}, {"type": "ordinal", "field": "county"}]}, "title": "COVID-19 WA Confirmed Cases and Deaths per 100K by County [101]"}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-b0b5bbc5424a0c779187630e681c4477": [{"fips": 53061, "day_num": 101, "confirmed": 3, "county": "Snohomish"}, {"fips": 53007, "day_num": 101, "confirmed": 1, "county": "Chelan"}, {"fips": 53033, "day_num": 101, "confirmed": 3, "county": "King"}, {"fips": 53037, "day_num": 101, "confirmed": 2, "county": "Kittitas"}, {"fips": 53031, "day_num": 101, "confirmed": 3, "county": "Jefferson"}, {"fips": 53071, "day_num": 101, "confirmed": 1, "county": "Walla Walla"}], "data-d751713988987e9331980363e24189ce": []}}, {"mode": "vega-lite"});
# </script>

# %%
map_state(107, 'WA', wa_counties, confirmed_wa, 1, 60, deaths_wa, 1, 5)
# Out:
# <div id="altair-viz-7985c6fb3be24671980d981c136c6df9"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-7985c6fb3be24671980d981c136c6df9") {
#       outputDiv = document.getElementById("altair-viz-7985c6fb3be24671980d981c136c6df9");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/WA-53-washington-counties.json", "format": {"feature": "cb_2015_washington_county_20m", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "white", "stroke": "lightgray"}, "height": 800, "projection": {"type": "mercator"}, "width": 1000}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": "geoshape", "encoding": {"color": {"type": "quantitative", "field": "confirmed", "scale": {"domain": [1, 60], "type": "log"}, "title": "Confirmed"}, "tooltip": [{"type": "quantitative", "field": "confirmed"}, {"type": "ordinal", "field": "county"}]}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-d8415c3624111690062df8cac1349af5"}, "key": "fips", "fields": ["confirmed", "county"]}}]}, {"data": {"name": "data-cf83c02104441edeac184e161f0d86bf"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "aggregate": "sum", "field": "deaths", "scale": {"domain": [1, 5], "type": "symlog"}, "title": "deaths"}, "stroke": {"value": "brown"}, "tooltip": [{"type": "quantitative", "field": "lat"}, {"type": "quantitative", "field": "long_"}, {"type": "quantitative", "field": "deaths"}, {"type": "ordinal", "field": "county"}]}, "title": "COVID-19 WA Confirmed Cases and Deaths per 100K by County [107]"}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-d8415c3624111690062df8cac1349af5": [{"fips": 53061, "day_num": 107, "confirmed": 17, "county": "Snohomish"}, {"fips": 53031, "day_num": 107, "confirmed": 3, "county": "Jefferson"}, {"fips": 53025, "day_num": 107, "confirmed": 1, "county": "Grant"}, {"fips": 53013, "day_num": 107, "confirmed": 25, "county": "Columbia"}, {"fips": 53035, "day_num": 107, "confirmed": 1, "county": "Kitsap"}, {"fips": 53029, "day_num": 107, "confirmed": 3, "county": "Island"}, {"fips": 53057, "day_num": 107, "confirmed": 2, "county": "Skagit"}, {"fips": 53007, "day_num": 107, "confirmed": 1, "county": "Chelan"}, {"fips": 53033, "day_num": 107, "confirmed": 15, "county": "King"}, {"fips": 53027, "day_num": 107, "confirmed": 1, "county": "Grays Harbor"}, {"fips": 53067, "day_num": 107, "confirmed": 1, "county": "Thurston"}, {"fips": 53053, "day_num": 107, "confirmed": 2, "county": "Pierce"}, {"fips": 53037, "day_num": 107, "confirmed": 7, "county": "Kittitas"}, {"fips": 53071, "day_num": 107, "confirmed": 1, "county": "Walla Walla"}], "data-cf83c02104441edeac184e161f0d86bf": [{"lat": 47.8691, "long_": -120.6188, "day_num": 107, "deaths": 1, "county": "Chelan"}, {"lat": 47.4902, "long_": -121.8048, "day_num": 107, "deaths": 1, "county": "King"}]}}, {"mode": "vega-lite"});
# </script>

# %%
map_state(114, 'WA', wa_counties, confirmed_wa, 1, 60, deaths_wa, 1, 5)
# Out:
# <div id="altair-viz-e560f74ce40544239a1b8b2b28835850"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-e560f74ce40544239a1b8b2b28835850") {
#       outputDiv = document.getElementById("altair-viz-e560f74ce40544239a1b8b2b28835850");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/WA-53-washington-counties.json", "format": {"feature": "cb_2015_washington_county_20m", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "white", "stroke": "lightgray"}, "height": 800, "projection": {"type": "mercator"}, "width": 1000}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": "geoshape", "encoding": {"color": {"type": "quantitative", "field": "confirmed", "scale": {"domain": [1, 60], "type": "log"}, "title": "Confirmed"}, "tooltip": [{"type": "quantitative", "field": "confirmed"}, {"type": "ordinal", "field": "county"}]}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-d6da5f765c747df7fc0a05dfa72154c8"}, "key": "fips", "fields": ["confirmed", "county"]}}]}, {"data": {"name": "data-f5cf0722984381e76037a405e4dc318a"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "aggregate": "sum", "field": "deaths", "scale": {"domain": [1, 5], "type": "symlog"}, "title": "deaths"}, "stroke": {"value": "brown"}, "tooltip": [{"type": "quantitative", "field": "lat"}, {"type": "quantitative", "field": "long_"}, {"type": "quantitative", "field": "deaths"}, {"type": "ordinal", "field": "county"}]}, "title": "COVID-19 WA Confirmed Cases and Deaths per 100K by County [114]"}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-d6da5f765c747df7fc0a05dfa72154c8": [{"fips": 53027, "day_num": 114, "confirmed": 1, "county": "Grays Harbor"}, {"fips": 53037, "day_num": 114, "confirmed": 9, "county": "Kittitas"}, {"fips": 53065, "day_num": 114, "confirmed": 2, "county": "Stevens"}, {"fips": 53029, "day_num": 114, "confirmed": 23, "county": "Island"}, {"fips": 53013, "day_num": 114, "confirmed": 25, "county": "Columbia"}, {"fips": 53005, "day_num": 114, "confirmed": 1, "county": "Benton"}, {"fips": 53057, "day_num": 114, "confirmed": 21, "county": "Skagit"}, {"fips": 53067, "day_num": 114, "confirmed": 3, "county": "Thurston"}, {"fips": 53063, "day_num": 114, "confirmed": 2, "county": "Spokane"}, {"fips": 53025, "day_num": 114, "confirmed": 11, "county": "Grant"}, {"fips": 53009, "day_num": 114, "confirmed": 1, "county": "Clallam"}, {"fips": 53035, "day_num": 114, "confirmed": 4, "county": "Kitsap"}, {"fips": 53007, "day_num": 114, "confirmed": 4, "county": "Chelan"}, {"fips": 53073, "day_num": 114, "confirmed": 5, "county": "Whatcom"}, {"fips": 53055, "day_num": 114, "confirmed": 6, "county": "San Juan"}, {"fips": 53015, "day_num": 114, "confirmed": 1, "county": "Cowlitz"}, {"fips": 53021, "day_num": 114, "confirmed": 1, "county": "Franklin"}, {"fips": 53033, "day_num": 114, "confirmed": 38, "county": "King"}, {"fips": 53053, "day_num": 114, "confirmed": 9, "county": "Pierce"}, {"fips": 53039, "day_num": 114, "confirmed": 9, "county": "Klickitat"}, {"fips": 53011, "day_num": 114, "confirmed": 1, "county": "Clark"}, {"fips": 53061, "day_num": 114, "confirmed": 50, "county": "Snohomish"}, {"fips": 53043, "day_num": 114, "confirmed": 9, "county": "Lincoln"}, {"fips": 53077, "day_num": 114, "confirmed": 4, "county": "Yakima"}, {"fips": 53071, "day_num": 114, "confirmed": 1, "county": "Walla Walla"}, {"fips": 53041, "day_num": 114, "confirmed": 2, "county": "Lewis"}, {"fips": 53045, "day_num": 114, "confirmed": 1, "county": "Mason"}, {"fips": 53031, "day_num": 114, "confirmed": 13, "county": "Jefferson"}], "data-f5cf0722984381e76037a405e4dc318a": [{"lat": 48.1629, "long_": -122.5486, "day_num": 114, "deaths": 1, "county": "Island"}, {"lat": 47.8691, "long_": -120.6188, "day_num": 114, "deaths": 1, "county": "Chelan"}, {"lat": 47 ...
# </script>

# %% [markdown]
# ### NY State

# %%
map_state(101, 'NY', ny_counties, confirmed_ny, 1, 1500, deaths_ny, 1, 20)
# Out:
# <div id="altair-viz-b816dd2e16ca42159f2c50583e4db3a6"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-b816dd2e16ca42159f2c50583e4db3a6") {
#       outputDiv = document.getElementById("altair-viz-b816dd2e16ca42159f2c50583e4db3a6");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/NY-36-new-york-counties.json", "format": {"feature": "cb_2015_new_york_county_20m", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "white", "stroke": "lightgray"}, "height": 800, "projection": {"type": "mercator"}, "width": 1000}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": "geoshape", "encoding": {"color": {"type": "quantitative", "field": "confirmed", "scale": {"domain": [1, 1500], "type": "log"}, "title": "Confirmed"}, "tooltip": [{"type": "quantitative", "field": "confirmed"}, {"type": "ordinal", "field": "county"}]}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-a8454155e785045384ba3a769198f07b"}, "key": "fips", "fields": ["confirmed", "county"]}}]}, {"data": {"name": "data-d751713988987e9331980363e24189ce"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "aggregate": "sum", "field": "deaths", "scale": {"domain": [1, 20], "type": "symlog"}, "title": "deaths"}, "stroke": {"value": "brown"}, "tooltip": [{"type": "quantitative", "field": "lat"}, {"type": "quantitative", "field": "long_"}, {"type": "quantitative", "field": "deaths"}, {"type": "ordinal", "field": "county"}]}, "title": "COVID-19 NY Confirmed Cases and Deaths per 100K by County [101]"}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-a8454155e785045384ba3a769198f07b": [{"fips": 36111, "day_num": 101, "confirmed": 2, "county": "Ulster"}, {"fips": 36103, "day_num": 101, "confirmed": 1, "county": "Suffolk"}, {"fips": 36119, "day_num": 101, "confirmed": 15, "county": "Westchester"}, {"fips": 36025, "day_num": 101, "confirmed": 2, "county": "Delaware"}, {"fips": 36091, "day_num": 101, "confirmed": 1, "county": "Saratoga"}, {"fips": 36059, "day_num": 101, "confirmed": 3, "county": "Nassau"}, {"fips": 36087, "day_num": 101, "confirmed": 2, "county": "Rockland"}, {"fips": 36061, "day_num": 101, "confirmed": 5, "county": "New York City"}, {"fips": 36043, "day_num": 101, "confirmed": 1, "county": "Herkimer"}], "data-d751713988987e9331980363e24189ce": []}}, {"mode": "vega-lite"});
# </script>

# %%
map_state(107, 'NY', ny_counties, confirmed_ny, 1, 1500, deaths_ny, 1, 20)
# Out:
# <div id="altair-viz-592e4b8de42d4ae8af3077ffd4e952fc"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-592e4b8de42d4ae8af3077ffd4e952fc") {
#       outputDiv = document.getElementById("altair-viz-592e4b8de42d4ae8af3077ffd4e952fc");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/NY-36-new-york-counties.json", "format": {"feature": "cb_2015_new_york_county_20m", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "white", "stroke": "lightgray"}, "height": 800, "projection": {"type": "mercator"}, "width": 1000}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": "geoshape", "encoding": {"color": {"type": "quantitative", "field": "confirmed", "scale": {"domain": [1, 1500], "type": "log"}, "title": "Confirmed"}, "tooltip": [{"type": "quantitative", "field": "confirmed"}, {"type": "ordinal", "field": "county"}]}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-4199765c68dc12b1649a18e1a51f4f09"}, "key": "fips", "fields": ["confirmed", "county"]}}]}, {"data": {"name": "data-21ae87d7ed347d8d34585ad815596bf0"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "aggregate": "sum", "field": "deaths", "scale": {"domain": [1, 20], "type": "symlog"}, "title": "deaths"}, "stroke": {"value": "brown"}, "tooltip": [{"type": "quantitative", "field": "lat"}, {"type": "quantitative", "field": "long_"}, {"type": "quantitative", "field": "deaths"}, {"type": "ordinal", "field": "county"}]}, "title": "COVID-19 NY Confirmed Cases and Deaths per 100K by County [107]"}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-4199765c68dc12b1649a18e1a51f4f09": [{"fips": 36059, "day_num": 107, "confirmed": 13, "county": "Nassau"}, {"fips": 36093, "day_num": 107, "confirmed": 8, "county": "Schenectady"}, {"fips": 36119, "day_num": 107, "confirmed": 55, "county": "Westchester"}, {"fips": 36091, "day_num": 107, "confirmed": 6, "county": "Saratoga"}, {"fips": 36103, "day_num": 107, "confirmed": 7, "county": "Suffolk"}, {"fips": 36043, "day_num": 107, "confirmed": 1, "county": "Herkimer"}, {"fips": 36061, "day_num": 107, "confirmed": 81, "county": "New York City"}, {"fips": 36113, "day_num": 107, "confirmed": 1, "county": "Warren"}, {"fips": 36027, "day_num": 107, "confirmed": 6, "county": "Dutchess"}, {"fips": 36057, "day_num": 107, "confirmed": 2, "county": "Montgomery"}, {"fips": 36105, "day_num": 107, "confirmed": 1, "county": "Sullivan"}, {"fips": 36111, "day_num": 107, "confirmed": 4, "county": "Ulster"}, {"fips": 36025, "day_num": 107, "confirmed": 2, "county": "Delaware"}, {"fips": 36041, "day_num": 107, "confirmed": 21, "county": "Hamilton"}, {"fips": 36083, "day_num": 107, "confirmed": 2, "county": "Rensselaer"}, {"fips": 36019, "day_num": 107, "confirmed": 1, "county": "Clinton"}, {"fips": 36115, "day_num": 107, "confirmed": 1, "county": "Washington"}, {"fips": 36121, "day_num": 107, "confirmed": 2, "county": "Wyoming"}, {"fips": 36039, "day_num": 107, "confirmed": 4, "county": "Greene"}, {"fips": 36031, "day_num": 107, "confirmed": 2, "county": "Essex"}, {"fips": 36087, "day_num": 107, "confirmed": 9, "county": "Rockland"}, {"fips": 36051, "day_num": 107, "confirmed": 1, "county": "Livingston"}, {"fips": 36017, "day_num": 107, "confirmed": 2, "county": "Chenango"}, {"fips": 36007, "day_num": 107, "confirmed": 1, "county": "Broome"}, {"fips": 36055, "day_num": 107, "confirmed": 1, "county": "Monroe"}, {"fips": 36107, "day_num": 107, "confirmed": 2, "county": "Tioga"}, {"fips": 36071, "day_num": 107, "confirmed": 8, "county": "Orange"}, {"fips": 36079, "day_num": 107, "confirmed": 2, "county": "Putnam"}, {"fips": 36003, "day_num": 107, "confirmed": 4, "county": "Allegany"}, {"fips": 36001, "day_num": 107, "confirmed": 11, "county": "Albany"}, {"fips": 36109, "day_num": 107, "confirmed": 1, "county": "Tompkins"}] ...
# </script>

# %%
map_state(114, 'NY', ny_counties, confirmed_ny, 1, 1500, deaths_ny, 1, 20)
# Out:
# <div id="altair-viz-0a183182de6e4622957f87b3b277c1ed"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-0a183182de6e4622957f87b3b277c1ed") {
#       outputDiv = document.getElementById("altair-viz-0a183182de6e4622957f87b3b277c1ed");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/NY-36-new-york-counties.json", "format": {"feature": "cb_2015_new_york_county_20m", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "white", "stroke": "lightgray"}, "height": 800, "projection": {"type": "mercator"}, "width": 1000}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": "geoshape", "encoding": {"color": {"type": "quantitative", "field": "confirmed", "scale": {"domain": [1, 1500], "type": "log"}, "title": "Confirmed"}, "tooltip": [{"type": "quantitative", "field": "confirmed"}, {"type": "ordinal", "field": "county"}]}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-af8b5061cee0eb62207e448d644c1acd"}, "key": "fips", "fields": ["confirmed", "county"]}}]}, {"data": {"name": "data-323b220310b3c8ea5cd4a35ab3ac4429"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "aggregate": "sum", "field": "deaths", "scale": {"domain": [1, 20], "type": "symlog"}, "title": "deaths"}, "stroke": {"value": "brown"}, "tooltip": [{"type": "quantitative", "field": "lat"}, {"type": "quantitative", "field": "long_"}, {"type": "quantitative", "field": "deaths"}, {"type": "ordinal", "field": "county"}]}, "title": "COVID-19 NY Confirmed Cases and Deaths per 100K by County [114]"}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-af8b5061cee0eb62207e448d644c1acd": [{"fips": 36093, "day_num": 114, "confirmed": 35, "county": "Schenectady"}, {"fips": 36001, "day_num": 114, "confirmed": 49, "county": "Albany"}, {"fips": 36117, "day_num": 114, "confirmed": 7, "county": "Wayne"}, {"fips": 36071, "day_num": 114, "confirmed": 169, "county": "Orange"}, {"fips": 36025, "day_num": 114, "confirmed": 10, "county": "Delaware"}, {"fips": 36011, "day_num": 114, "confirmed": 2, "county": "Cayuga"}, {"fips": 36055, "day_num": 114, "confirmed": 15, "county": "Monroe"}, {"fips": 36087, "day_num": 114, "confirmed": 330, "county": "Rockland"}, {"fips": 36119, "day_num": 114, "confirmed": 482, "county": "Westchester"}, {"fips": 36033, "day_num": 114, "confirmed": 1, "county": "Franklin"}, {"fips": 36003, "day_num": 114, "confirmed": 4, "county": "Allegany"}, {"fips": 36043, "day_num": 114, "confirmed": 7, "county": "Herkimer"}, {"fips": 36017, "day_num": 114, "confirmed": 6, "county": "Chenango"}, {"fips": 36029, "day_num": 114, "confirmed": 13, "county": "Erie"}, {"fips": 36113, "day_num": 114, "confirmed": 3, "county": "Warren"}, {"fips": 36057, "day_num": 114, "confirmed": 8, "county": "Montgomery"}, {"fips": 36079, "day_num": 114, "confirmed": 84, "county": "Putnam"}, {"fips": 36061, "day_num": 114, "confirmed": 1222, "county": "New York City"}, {"fips": 36041, "day_num": 114, "confirmed": 42, "county": "Hamilton"}, {"fips": 36111, "day_num": 114, "confirmed": 36, "county": "Ulster"}, {"fips": 36075, "day_num": 114, "confirmed": 1, "county": "Oswego"}, {"fips": 36063, "day_num": 114, "confirmed": 5, "county": "Niagara"}, {"fips": 36027, "day_num": 114, "confirmed": 51, "county": "Dutchess"}, {"fips": 36073, "day_num": 114, "confirmed": 4, "county": "Orleans"}, {"fips": 36053, "day_num": 114, "confirmed": 9, "county": "Madison"}, {"fips": 36083, "day_num": 114, "confirmed": 19, "county": "Rensselaer"}, {"fips": 36021, "day_num": 114, "confirmed": 19, "county": "Columbia"}, {"fips": 36031, "day_num": 114, "confirmed": 10, "county": "Essex"}, {"fips": 36037, "day_num": 114, "confirmed": 3, "county": "Genesee"}, {"fips": 36059, "day_num": 114, "confirmed": 241, "county": "Nassau"}, {"fips": 36065, "day_num": 114, "confirmed": 3, "county": "On ...
# </script>

# %% [markdown]
# ## COVID-19 Confirmed Cases and Deaths by WA and NY County Slider

# %%
# pivot confirmed cases
confirmed_pv_wa = confirmed_wa[['fips', 'day_num', 'confirmed']]
confirmed_pv_wa['fips'] = confirmed_pv_wa['fips'].astype(str)
confirmed_pv_wa['day_num'] = confirmed_pv_wa['day_num'].astype(str)
confirmed_pv_wa['confirmed'] = confirmed_pv_wa['confirmed'].astype('int64')
confirmed_pv_wa = confirmed_pv_wa.pivot_table(index='fips', columns='day_num', values='confirmed', fill_value=0).reset_index()

# pivot deaths
deaths_pv_wa = deaths_wa[['lat', 'long_', 'day_num', 'deaths']]
deaths_pv_wa['day_num'] = deaths_pv_wa['day_num'].astype(str)
deaths_pv_wa['deaths'] = deaths_pv_wa['deaths'].astype('int64')
deaths_pv_wa = deaths_pv_wa.pivot_table(index=['lat', 'long_'], columns='day_num', values='deaths', fill_value=0).reset_index()

# Extract column names for slider
column_names = confirmed_pv_wa.columns.tolist()

# Remove first element (`fips`)
column_names.pop(0)

# Convert to int
column_values = [None] * len(column_names)
for i in range(0, len(column_names)): column_values[i] = int(column_names[i])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/tmp/1586814074438-0/PythonShell.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /local_disk0/tmp/1586814074438-0/PythonShell.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import errno
# /local_disk0/tmp/1586814074438-0/PythonShell.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import linecache
# /local_disk0/tmp/1586814074438-0/PythonShell.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import six
# /local_disk0/tmp/1586814074438-0/PythonShell.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import six.moves.queue
# </div>

# %%
# Disable max_rows to see more data
alt.data_transformers.disable_max_rows()

# Topographic information
us_states = alt.topo_feature(topo_usa, 'states')
us_counties = alt.topo_feature(topo_usa, 'counties')

# state county boundaries
base_state = alt.Chart(wa_counties).mark_geoshape(
    fill='white',
    stroke='lightgray',
).properties(
    width=1000,
    height=800,
).project(
    type='mercator'
)

# Slider choices
min_day_num = column_values[0]
max_day_num = column_values[len(column_values)-1]
slider = alt.binding_range(min=min_day_num, max=max_day_num, step=1)
slider_selection = alt.selection_single(fields=['day_num'], bind=slider, name="day_num", init={'day_num':min_day_num})


# Confirmed cases by county
base_state_counties = alt.Chart(us_counties).mark_geoshape(
    stroke='black',
    strokeWidth=0.05
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(confirmed_pv_wa, 'fips', column_names)  
).transform_fold(
    column_names, as_=['day_num', 'confirmed']
).transform_calculate(
    state_id = "(datum.id / 1000)|0",
    day_num = 'parseInt(datum.day_num)',
    confirmed = 'isValid(datum.confirmed) ? datum.confirmed : -1'
).encode(
    color = alt.condition(
        'datum.confirmed > 0',      
        alt.Color('confirmed:Q', scale=alt.Scale(domain=(1, 60), type='symlog')),
        alt.value('white')
      )  
).properties(
  # update figure title
  title=f'COVID-19 WA State Confirmed Cases per 100K by County'
).transform_filter(
    (alt.datum.state_id)==53
# ).add_selection(
#     slider_selection
).transform_filter(
    slider_selection
)


# deaths by long, latitude
points = alt.Chart(
  deaths_pv_wa
).mark_point(
  opacity=0.75, filled=True
).transform_fold(
  column_names, as_=['day_num', 'deaths']
).transform_calculate(
    day_num = 'parseInt(datum.day_num)',
    deaths = 'isValid(datum.deaths) ? datum.deaths : -1'  
).encode(
  longitude='long_:Q',
  latitude='lat:Q',
  size=alt.Size('deaths:Q', scale=alt.Scale(domain=(1, 5), type='symlog'), title='deaths'),
  color=alt.value('#BD595D'),
  stroke=alt.value('brown'),
).add_selection(
    slider_selection
).transform_filter(
    slider_selection
)

# confirmed cases (base_counties) and deaths (points)
(base_state + base_state_counties + points)
# Out:
# <div id="altair-viz-438f1fad2d2c43b28650d9da150c5a90"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-438f1fad2d2c43b28650d9da150c5a90") {
#       outputDiv = document.getElementById("altair-viz-438f1fad2d2c43b28650d9da150c5a90");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/WA-53-washington-counties.json", "format": {"feature": "cb_2015_washington_county_20m", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "white", "stroke": "lightgray"}, "height": 800, "projection": {"type": "mercator"}, "width": 1000}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": {"type": "geoshape", "stroke": "black", "strokeWidth": 0.05}, "encoding": {"color": {"condition": {"type": "quantitative", "field": "confirmed", "scale": {"domain": [1, 60], "type": "symlog"}, "test": "datum.confirmed > 0"}, "value": "white"}}, "title": "COVID-19 WA State Confirmed Cases per 100K by County", "transform": [{"lookup": "id", "from": {"data": {"name": "data-429990f29fb410cdfc84234a9b76b3c4"}, "key": "fips", "fields": ["101", "102", "103", "104", "105", "106", "107", "108", "109", "110", "111", "112", "113", "114"]}}, {"fold": ["101", "102", "103", "104", "105", "106", "107", "108", "109", "110", "111", "112", "113", "114"], "as": ["day_num", "confirmed"]}, {"calculate": "(datum.id / 1000)|0", "as": "state_id"}, {"calculate": "parseInt(datum.day_num)", "as": "day_num"}, {"calculate": "isValid(datum.confirmed) ? datum.confirmed : -1", "as": "confirmed"}, {"filter": "(datum.state_id === 53)"}, {"filter": {"selection": "day_num"}}]}, {"data": {"name": "data-7802e2a2ae71674c1305c3f46ed2d554"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "field": "deaths", "scale": {"domain": [1, 5], "type": "symlog"}, "title": "deaths"}, "stroke": {"value": "brown"}}, "selection": {"day_num": {"type": "single", "fields": ["day_num"], "bind": {"input": "range", "max": 114, "min": 101, "step": 1}, "init": {"day_num": 101}}}, "transform": [{"fold": ["101", "102", "103", "104", "105", "106", "107", "108", "109", "110", "111", "112", "113", "114"], "as": ["day_num", "deaths"]}, {"calculate": "parseInt(datum.day_num)", "as": "day_num"}, {"calculate": "isValid(datum.deaths) ? datum.deaths : -1", "as": "deaths"}, {"filter": {"selection": "day_num"}}]}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-429990f29fb410cdfc84234a9b76b3c4": [{"fips": "53005", "101": 0, "102": 0, "103": 0, "104": 0, "105": 0, "106": 0, "107": 0, "108": 0, "109": 0, "110": 0, "111": 0, "112": 0, "113": 1, "114": 1}, {"fips": "53007", "101": 1, "102": 1, "103": 1, "104": 1, "105": 1, "106": 1, "107": 1, "108": 1, "109": 1, "110": 1, "111": 4, "112": 4, "113": 4, "114": 4}, {"fips": "53009", "101": 0, "102": 0, "103": 0, "104": 0, "105": 0, "106": 0, "107": 0, "108": 0, "109": 0, "110": 0, "111": 0, "112": 0, "113": 1, "114": 1}, {"fips": "53011", "101": 0, "102": 0, "103": 0, "104": 0, "105": 0, "106": 0, "107": 0, "108": 0, "109": 0, "110": 0, "111": 0, "112": 0, "113": 0, "114": 1}, {"fips": "53013", "101": 0, "102": 0, "103": 0, "104": 0, "105": 0, "106": 25, "107": 25, "108": 25, "109": 25, "110": 25, "111": 25, "112": 25, "113": 25, "114": 25}, {"fips": "53015", "101": 0, "102": 0, "103": 0, "104": 0, "105": 0, "106": 0, "107": 0, "108": 0, "109": 0, "110": 0, "111": 0, "112": 0, "113": 0, "114": 1}, {"fips": "53021", "101": 0, "102": 0, "103": 0, "104": 0, "105": 0, "106": 0, "107": 0, "108": 0, "109": 0, "110": 0, "111": 1, "112": 1, "113": 1, "114": 1}, {"fips": "53025", "101": 0, "102": 0, "103": 0, "104": 0, "105": 0, "106": 0, "107": 1, "108": 1, "109": 1, "110": 6, "111": 6, "112": 6, "113": 8, "114": 11}, {"fips": "53027", "101": 0, "102": 0, "103": 0, "104": 0, "105": 0, "106": 1, "107": 1, "108": 1, "109": 1, "110": 1, "111": 1, "112": 1, "113": 1, "114": 1 ...
