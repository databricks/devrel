# %% [markdown]
# ## NYT COVID-19 Analysis
# This notebook processes and performs quick analysis from the [New York Times COVID-19 dataset](https://github.com/nytimes/covid-19-data).  The data is updated in the `/databricks-datasets/COVID/covid-19-data/` location regularly so you can access the data directly.

# %%
# Standard Libraries
import io

# External Libraries
import requests
import numpy as np
import pandas as pd
import altair as alt
from vega_datasets import data

# topographical
topo_usa = 'https://vega.github.io/vega-datasets/data/us-10m.json'
topo_wa = 'https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/WA-53-washington-counties.json'
topo_king = 'https://raw.githubusercontent.com/johan/world.geo.json/master/countries/USA/WA/King.geo.json'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/jinja2/runtime.py:318: DeprecationWarning: Using or importing the ABCs from &#39;collections&#39; instead of from &#39;collections.abc&#39; is deprecated, and in 3.8 it will stop working
#   from collections import Mapping
# </div>

# %% [markdown]
# ### Download Mapping County FIPS to lat, long_

# %%
# %sh mkdir -p /dbfs/tmp/dennylee/COVID/map_fips/ && wget -O /dbfs/tmp/dennylee/COVID/map_fips/countyfips_lat_long.csv https://raw.githubusercontent.com/dennyglee/tech-talks/master/datasets/countyfips_lat_long.csv && ls -al /dbfs/tmp/dennylee/COVID/map_fips/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">--2020-04-17 22:32:47--  https://raw.githubusercontent.com/dennyglee/tech-talks/master/datasets/countyfips_lat_long.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.52.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.52.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 129178 (126K) [text/plain]
# Saving to: ‘/dbfs/tmp/dennylee/COVID/map_fips/countyfips_lat_long.csv’
#
#      0K .......... .......... .......... .......... .......... 39% 3.06M 0s
#     50K .......... .......... .......... .......... .......... 79% 7.03M 0s
#    100K .......... .......... ......                          100% 20.9M=0.02s
#
# 2020-04-17 22:32:47 (5.10 MB/s) - ‘/dbfs/tmp/dennylee/COVID/map_fips/countyfips_lat_long.csv’ saved [129178/129178]
#
# total 135
# drwxrwxrwx 2 root root   4096 Apr 17  2020 .
# drwxrwxrwx 2 root root   4096 Apr 17 22:29 ..
# -rwxrwxrwx 1 root root 129178 Apr 17  2020 countyfips_lat_long.csv
# </div>

# %%
# Create mapping of county FIPS to centroid long_ and lat
map_fips = spark.read.option("header", True).option("inferSchema", True).csv("/tmp/dennylee/COVID/map_fips/countyfips_lat_long.csv")
map_fips = (map_fips
              .withColumnRenamed("STATE", "state")
              .withColumnRenamed("COUNTYNAME", "county")
              .withColumnRenamed("LAT", "lat")
              .withColumnRenamed("LON", "long_"))
map_fips.createOrReplaceTempView("map_fips")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
map_fips_dedup = spark.sql("""select fips, min(state) as state, min(county) as county, min(long_) as long_, min(lat) as lat from map_fips group by fips""")
map_fips_dedup.createOrReplaceTempView("map_fips_dedup")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Download 2019 Population Estimates

# %%
# %sh mkdir -p /dbfs/tmp/dennylee/COVID/population_estimates_by_county/ && wget -O /dbfs/tmp/dennylee/COVID/population_estimates_by_county/co-est2019-alldata.csv https://raw.githubusercontent.com/databricks/tech-talks/master/datasets/co-est2019-alldata.csv && ls -al /dbfs/tmp/dennylee/COVID/population_estimates_by_county/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">--2020-04-17 22:33:51--  https://raw.githubusercontent.com/databricks/tech-talks/master/datasets/co-est2019-alldata.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.52.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.52.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3644730 (3.5M) [text/plain]
# Saving to: ‘/dbfs/tmp/dennylee/COVID/population_estimates_by_county/co-est2019-alldata.csv’
#
#      0K .......... .......... .......... .......... ..........  1% 3.71M 1s
#     50K .......... .......... .......... .......... ..........  2% 7.98M 1s
#    100K .......... .......... .......... .......... ..........  4% 7.40M 1s
#    150K .......... .......... .......... .......... ..........  5% 23.2M 0s
#    200K .......... .......... .......... .......... ..........  7% 28.3M 0s
#    250K .......... .......... .......... .......... ..........  8% 11.5M 0s
#    300K .......... .......... .......... .......... ..........  9% 30.3M 0s
#    350K .......... .......... .......... .......... .......... 11% 25.4M 0s
#    400K .......... .......... .......... .......... .......... 12% 26.5M 0s
#    450K .......... .......... .......... .......... .......... 14% 26.5M 0s
#    500K .......... .......... .......... .......... .......... 15% 31.8M 0s
#    550K .......... .......... .......... .......... .......... 16% 25.2M 0s
#    600K .......... .......... .......... .......... .......... 18% 24.4M 0s
#    650K .......... .......... .......... .......... .......... 19% 29.7M 0s
#    700K .......... .......... .......... .......... .......... 21% 30.2M 0s
#    750K .......... .......... .......... .......... .......... 22% 24.2M 0s
#   3200K .......... .......... .......... .......... .......... 91% 27.1M 0s
#   3250K .......... .......... .......... .......... .......... 92% 31.4M 0s
#   3300K .......... .......... .......... .......... .......... 94% 31.7M 0s
#   3350K .......... .......... .......... .......... .......... 95% 26.9M 0s
#   3400K .......... .......... .......... .......... .......... 96% 31.5M 0s
#   3450K .......... .......... .......... .......... .......... 98% 31.3M 0s
#   3500K .......... .......... .......... .......... .......... 99% 26.9M 0s
#   3550K .........                                             100% 35.4M=0.1s
#
# 2020-04-17 22:33:51 (24.2 MB/s) - ‘/dbfs/tmp/dennylee/COVID/population_estimates_by_county/co-est2019-alldata.csv’ saved [3644730/3644730]
#
# total 5307
# drwxrwxrwx 2 root root    4096 Apr 17 22:33 .
# drwxrwxrwx 2 root root    4096 Apr 17 22:29 ..
# -rwxrwxrwx 1 root root 1781101 Apr 15 05:49 CO-EST2014-alldata.csv
# -rwxrwxrwx 1 root root 3644730 Apr 17 22:33 co-est2019-alldata.csv
# </div>

# %%
map_popest_county = spark.read.option("header", True).option("inferSchema", True).csv("/tmp/dennylee/COVID/population_estimates_by_county/co-est2019-alldata.csv")
map_popest_county.createOrReplaceTempView("map_popest_county")
fips_popest_county = spark.sql("select State * 1000 + substring(cast(1000 + County as string), 2, 3) as fips, STNAME, CTYNAME, census2010pop, POPESTIMATE2019 from map_popest_county")
fips_popest_county.createOrReplaceTempView("fips_popest_county")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Specify `nyt_daily` table
# * Source: `/databricks-datasets/COVID/covid-19-data/`
# * Contains the COVID-19 daily reports

# %%
nyt_daily = spark.read.option("inferSchema", True).option("header", True).csv("/databricks-datasets/COVID/covid-19-data/us-counties.csv")
nyt_daily.createOrReplaceTempView("nyt_daily")
display(nyt_daily)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>county</th><th>state</th><th>fips</th><th>cases</th><th>deaths</th></tr></thead><tbody><tr><td>2020-01-21T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-22T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-23T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-24T00:00:00.000+0000</td><td>Cook</td><td>Illinois</td><td>17031</td><td>1</td><td>0</td></tr><tr><td>2020-01-24T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-25T00:00:00.000+0000</td><td>Orange</td><td>California</td><td>6059</td><td>1</td><td>0</td></tr><tr><td>2020-01-25T00:00:00.000+0000</td><td>Cook</td><td>Illinois</td><td>17031</td><td>1</td><td>0</td></tr><tr><td>2020-01-25T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-26T00:00:00.000+0000</td><td>Maricopa</td><td>Arizona</td><td>4013</td><td>1</td><td>0</td></tr><tr><td>2020-01-26T00:00:00.000+0000</td><td>Los Angeles</td><td>California</td><td>6037</td><td>1</td><td>0</td></tr><tr><td>2020-01-26T00:00:00.000+0000</td><td>Orange</td><td>California</td><td>6059</td><td>1</td><td>0</td></tr><tr><td>2020-01-26T00:00:00.000+0000</td><td>Cook</td><td>Illinois</td><td>17031</td><td>1</td><td>0</td></tr><tr><td>2020-01-26T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-27T00:00:00.000+0000</td><td>Maricopa</td><td>Arizona</td><td>4013</td><td>1</td><td>0</td></tr><tr><td>2020-01-27T00:00:00.000+0000</td><td>Los Angeles</td><td>California</td><td>6037</td><td>1</td><td>0</td></tr><tr><td>2020-01-27T00:00:00.000+0000</td><td>Orange</td><td>California</td><td>6059</td><td>1</td><td>0</td></tr><tr><td>2020-01-27T00:00:00.000+0000</td><td>Cook</td><td>Illinois</td><td>17031</td><td>1</td><td>0</td></tr><tr><td>2020-01-27T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-28T00:00:00.000+0000</td><td>Maricopa</td><td>Arizona</td><td>4013</td><td>1</td><td>0</td></tr><tr><td>2020-01-28T00:00:00.000+0000</td><td>Los Angeles</td><td>California</td><td>6037</td><td>1</td><td>0</td></tr><tr><td>2020-01-28T00:00:00.000+0000</td><td>Orange</td><td>California</td><td>6059</td><td>1</td><td>0</td></tr><tr><td>2020-01-28T00:00:00.000+0000</td><td>Cook</td><td>Illinois</td><td>17031</td><td>1</td><td>0</td></tr><tr><td>2020-01-28T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-29T00:00:00.000+0000</td><td>Maricopa</td><td>Arizona</td><td>4013</td><td>1</td><td>0</td></tr><tr><td>2020-01-29T00:00:00.000+0000</td><td>Los Angeles</td><td>California</td><td>6037</td><td>1</td><td>0</td></tr><tr><td>2020-01-29T00:00:00.000+0000</td><td>Orange</td><td>California</td><td>6059</td><td>1</td><td>0</td></tr><tr><td>2020-01-29T00:00:00.000+0000</td><td>Cook</td><td>Illinois</td><td>17031</td><td>1</td><td>0</td></tr><tr><td>2020-01-29T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020-01-30T00:00:00.000+0000</td><td>Maricopa</td><td>Arizona</td><td>4013</td><td>1</td><td>0</td></tr><tr><td>2020-01-30T00:00:00.000+0000</td><td>Los Angeles</td><td>California</td><td>6037</td><td>1</td><td>0</td></tr><tr><td>2020-01-30T00:00:00.000+0000</td><td>Orange</td><td>California</td><td>6059</td><td>1</td><td>0</td></tr><tr><td>2020-01-30T00:00:00.000+0000</td><td>Cook</td><td>Illinois</td><td>17031</td><td>2</td><td>0</td></tr><tr><td>2020-01-30T00:00:00.000+0000</td><td>Snohomish</td><td>Washington</td><td>53061</td><td>1</td><td>0</td></tr><tr><td>2020- ...

# %% [markdown]
# # COVID-19 Cases and Deaths for Specific Counties
# Focusing on two-week window around when educational facilites were closed
# * Top 10 Washington State counties (3/13/2020)
# * Top 10 NY State counties (3/18/2020)
# The queries are using the US Census Population Estimates for 2019

# %%
# WA State 2 week window
wa_state_window = spark.sql("""
SELECT date, 100 + datediff(date, '2020-03-06T00:00:00.000+0000') as day_num, county, fips, cases, deaths, 100000.*cases/population_estimate AS cases_per_100Kpop, 100000.*deaths/population_estimate AS deaths_per_100Kpop
  from (
SELECT CAST(f.date AS date) AS date, f.county, f.fips, SUM(f.cases) AS cases, SUM(f.deaths) AS deaths, MAX(p.POPESTIMATE2019) AS population_estimate 
  FROM nyt_daily f 
    JOIN fips_popest_county p
      ON p.fips = f.fips
 WHERE f.state = 'Washington' 
   AND date BETWEEN '2020-03-06T00:00:00.000+0000' AND '2020-03-20T00:00:00.000+0000'
 GROUP BY f.date, f.county, f.fips
) a""")
wa_state_window.createOrReplaceTempView("wa_state_window")

# NY State 2 week window
ny_state_window = spark.sql("""
SELECT date, 100 + datediff(date, '2020-03-11T00:00:00.000+0000') as day_num, county, fips, cases, deaths, 100000.*cases/population_estimate AS cases_per_100Kpop, 100000.*deaths/population_estimate AS deaths_per_100Kpop
  FROM (
SELECT CAST(f.date AS date) AS date, f.county, p.fips, SUM(f.cases) as cases, SUM(f.deaths) as deaths, MAX(p.POPESTIMATE2019) AS population_estimate  
  FROM nyt_daily f 
    JOIN fips_popest_county p
      ON p.fips = coalesce(f.fips, 36061)
 WHERE f.state = 'New York' 
   AND date BETWEEN '2020-03-11T00:00:00.000+0000' AND '2020-03-25T00:00:00.000+0000'
 GROUP BY f.date, f.county, p.fips
) a""")
ny_state_window.createOrReplaceTempView("ny_state_window")

# NY State 2 week window (-1 week)
ny_state_window_m1 = spark.sql("""
SELECT date, 100 + datediff(date, '2020-03-06T00:00:00.000+0000') as day_num, county, fips, cases, deaths, 100000.*cases/population_estimate AS cases_per_100Kpop, 100000.*deaths/population_estimate AS deaths_per_100Kpop
  FROM (
SELECT CAST(f.date AS date) AS date, f.county, p.fips, SUM(f.cases) as cases, SUM(f.deaths) as deaths, MAX(p.POPESTIMATE2019) AS population_estimate  
  FROM nyt_daily f 
    JOIN fips_popest_county p
      ON p.fips = coalesce(f.fips, 36061)
 WHERE f.state = 'New York' 
   AND date BETWEEN '2020-03-06T00:00:00.000+0000' AND '2020-03-20T00:00:00.000+0000'
 GROUP BY f.date, f.county, p.fips
) a""")
ny_state_window_m1.createOrReplaceTempView("ny_state_window_m1")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## COVID-19 Cases for WA and NY Counties

# %%
# %sql
SELECT f.date, f.county, f.cases 
  FROM wa_state_window f
  JOIN (
      SELECT county, sum(cases) as cases FROM wa_state_window GROUP BY county ORDER BY cases DESC LIMIT 10
    ) x ON x.county = f.county
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>county</th><th>cases</th></tr></thead><tbody><tr><td>2020-03-11</td><td>Island</td><td>1</td></tr><tr><td>2020-03-11</td><td>King</td><td>235</td></tr><tr><td>2020-03-12</td><td>Pierce</td><td>17</td></tr><tr><td>2020-03-13</td><td>Snohomish</td><td>132</td></tr><tr><td>2020-03-20</td><td>Island</td><td>19</td></tr><tr><td>2020-03-07</td><td>Snohomish</td><td>26</td></tr><tr><td>2020-03-15</td><td>Kitsap</td><td>5</td></tr><tr><td>2020-03-12</td><td>Spokane</td><td>4</td></tr><tr><td>2020-03
td></tr><tr><td>2020-03-15</td><td>Nassau</td><td>7.22221730915</td></tr><tr><td>2020-03-07</td><td>Westchester</td><td>7.1317387179</td></tr><tr><td>2020-03-08</td><td>Suffolk</td><td>0.06772310191</td></tr><tr><td>2020-03-13</td><td>Nassau</td><td>3.75850084456</td></tr><tr><td>2020-03-13</td><td>Orange</td><td>0.77934223515</td></tr><tr><td>2020-03-16</td><td>Nassau</td><td>8.03287435405</td></tr><tr><td>2020-03-20</td><td>New York City</td><td>270.64430290058</td></tr><tr><td>2020-03-18</td><td>Suffolk</td><td>7.85587982129</td></tr><tr><td>2020-03-08</td><td>Westchester</td><td>8.37204110362</td></tr><tr><td>2020-03-12</td><td>Dutchess</td><td>0.33988403157</td></tr><tr><td>2020-03-12</td><td>Monroe</td><td>0.13481267778</td></tr><tr><td>2020-03-12</td><td>Suffolk</td><td>1.42218514006</td></tr><tr><td>2020-03-17</td><td>Monroe</td><td>1.48293945563</td></tr><tr><td>2020-03-12</td><td>Westchester</td><td>15.19370422509</td></tr><tr><td>2020-03-20</td><td>Monroe</td><td>4.3140056891</td></tr><tr><td>2020-03-13</td><td>Westchester</td><td>16.22728954652</td></tr><tr><td>2020-03-11</td><td>Monroe</td><td>0.13481267778</td></tr><tr><td>2020-03-11</td><td>New York City</td><td>3.19271863676</td></tr><tr><td>2020-03-09</td><td>Nassau</td><td>1.25283361485</td></tr><tr><td>2020-03-17</td><td>New York City</td><td>39.60199078287</td></tr><tr><td>2020-03-18</td><td>New York City</td><td>82.21250489653</td></tr><tr><td>2020-03-17</td><td>Nassau</td><td>9.65418844386</td></tr><tr><td>2020-03-19</td><td>Rockland</td><td>16.26819812824</td></tr><tr><td>2020-03-20</td><td>Westchester</td><td>112.76415856853</td></tr><tr><td>2020-03-13</td><td>Rockland</td><td>2.76252421046</td></tr><tr><td>2020-03-18</td><td>Dutchess</td><td>6.79768063137</td></tr><tr><td>2020-03-19</td><td>Nassau</td><td>28.15190828668</td></tr><tr><td>2020-03-17</td><td>Westchester</td><td>39.17288368238</td></tr><tr><td>2020-03-09</td><td>New York City</td><td>1.22796870645</td></tr><tr><td>2020-03-15</td><td>New York City</td><td>20.26148365635</td></tr><tr><td>2020-03-16</td><td>Orange</td><td>2.85758819556</td></tr><tr><td>2020-03-14</td><td>Rockland</td><td>3.68336561394</td></tr><tr><td>2020-03-15</td><td>Monroe</td><td>0.26962535557</td></tr><tr><td>2020-03-13</td><td>Dutchess</td><td>1.01965209471</td></tr><tr><td>2020-03-12< ...

# %% [markdown]
# ## Visualize Cases by State Choropleth Maps
# * Join the data with `map_fips_dedup` to obtain the county centroid lat, long_

# %%
# Extract Day Number and county centroid lat, long_
wa_daynum = spark.sql("""select f.fips, f.county, f.date, f.day_num, cases as confirmed, cast(f.cases_per_100Kpop as int) as confirmed_per100K, deaths, cast(f.deaths_per_100Kpop as int) as deaths_per100K, m.lat, m.long_ from wa_state_window f join map_fips_dedup m on m.fips = f.fips""")
wa_daynum.createOrReplaceTempView("wa_daynum")
ny_daynum = spark.sql("""select cast(f.fips as int) as fips, f.county, f.date, f.day_num, cases as confirmed, cast(f.cases_per_100Kpop as int) as confirmed_per100K, deaths, cast(f.deaths_per_100Kpop as int) as deaths_per100K, m.lat, m.long_ from ny_state_window f join map_fips_dedup m on m.fips = f.fips""")
ny_daynum.createOrReplaceTempView("ny_daynum")
ny_daynum_m1 = spark.sql("""select cast(f.fips as int) as fips, f.county, f.date, f.day_num, cases as confirmed, cast(f.cases_per_100Kpop as int) as confirmed_per100K, deaths, cast(f.deaths_per_100Kpop as int) as deaths_per100K, m.lat, m.long_ from ny_state_window_m1 f join map_fips_dedup m on m.fips = f.fips""")
ny_daynum_m1.createOrReplaceTempView("ny_daynum_m1")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Obtain Topography
topo_usa = 'https://vega.github.io/vega-datasets/data/us-10m.json'
topo_wa = 'https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/WA-53-washington-counties.json'
topo_ny = 'https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/NY-36-new-york-counties.json'
us_counties = alt.topo_feature(topo_usa, 'counties')
wa_counties = alt.topo_feature(topo_wa, 'cb_2015_washington_county_20m')
ny_counties = alt.topo_feature(topo_ny, 'cb_2015_new_york_county_20m')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Review WA
confirmed_wa = wa_daynum.select("fips", "day_num", "date", "confirmed", "confirmed_per100K", "county").where("confirmed > 0").toPandas()
confirmed_wa['date'] = confirmed_wa['date'].astype(str)
deaths_wa = wa_daynum.select("lat", "long_", "day_num", "date", "deaths", "deaths_per100K", "county").where("deaths > 0").toPandas()
deaths_wa['date'] = deaths_wa['date'].astype(str)

# Review NY
confirmed_ny = ny_daynum.select("fips", "day_num", "date", "confirmed", "confirmed_per100K", "county").where("confirmed > 0").toPandas()
confirmed_ny['date'] = confirmed_ny['date'].astype(str)
deaths_ny = ny_daynum.select("lat", "long_", "day_num", "date", "deaths", "deaths_per100K", "county").where("deaths > 0").toPandas()
deaths_ny['date'] = deaths_ny['date'].astype(str)

# Review NY -1 week
confirmed_ny_m1 = ny_daynum_m1.select("fips", "day_num", "date", "confirmed", "confirmed_per100K", "county").where("confirmed > 0").toPandas()
confirmed_ny_m1['date'] = confirmed_ny_m1['date'].astype(str)
deaths_ny_m1 = ny_daynum_m1.select("lat", "long_", "day_num", "date", "deaths", "deaths_per100K", "county").where("deaths > 0").toPandas()
deaths_ny_m1['date'] = deaths_ny_m1['date'].astype(str)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# State Choropleth Map Visualization Function
def map_state(curr_day_num, state_txt, state_counties, confirmed, confirmed_min, confirmed_max, deaths, deaths_min, deaths_max):
  # Get date_str
  date_str = confirmed[confirmed['day_num'] == 101]['date'].head(1).item()
  
  # State
  base_state = alt.Chart(state_counties).mark_geoshape(
      fill='white',
      stroke='lightgray',
  ).properties(
      width=800,
      height=600,
  ).project(
      type='mercator'
  )

  # counties
  base_state_counties = alt.Chart(us_counties).mark_geoshape(
  ).transform_lookup(
    lookup='id',
    from_=alt.LookupData(confirmed[(confirmed['confirmed_per100K'] > 0) & (confirmed['day_num'] == curr_day_num)], 'fips', ['confirmed_per100K', 'confirmed', 'county', 'date', 'fips'])  
  ).encode(
     color=alt.Color('confirmed_per100K:Q', scale=alt.Scale(type='log', domain=[confirmed_min, confirmed_max]), title='Confirmed per 100K'),
    tooltip=[
      alt.Tooltip('fips:O'),
      alt.Tooltip('confirmed:Q'),
      alt.Tooltip('confirmed_per100K:Q'),
      alt.Tooltip('county:N'),
      alt.Tooltip('date:N'),
    ],
  )

  # deaths by long, latitude
  points = alt.Chart(deaths[(deaths['deaths_per100K'] > 0) & (deaths['day_num'] == curr_day_num)]).mark_point(opacity=0.75, filled=True).encode(
    longitude='long_:Q',
    latitude='lat:Q',
    size=alt.Size('sum(deaths_per100K):Q', scale=alt.Scale(type='symlog', domain=[deaths_min, deaths_max]), title='Deaths per 100K'),
    color=alt.value('#BD595D'),
    stroke=alt.value('brown'),
    tooltip=[
      alt.Tooltip('lat'),
      alt.Tooltip('long_'),
      alt.Tooltip('deaths'),
      alt.Tooltip('county:N'),      
      alt.Tooltip('date:N'),      
    ],
  ).properties(
    # update figure title
    title=f'COVID-19 {state_txt} Confirmed Cases and Deaths per 100K by County [{curr_day_num}, {date_str}]'
  )

  return (base_state + base_state_counties + points)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# | Factors | WA | NY |
# | ------- | -- | -- |
# | Educational Facilities Closed | 3/13/2020 | 3/18/2020 |
# | Day 00 | 3/6/2020 | 3/11/2020 |
# | Day 14 | 3/20/2020 | 3/25/2020 |
# | Max Cases | 794 | 20011 |
# | Max Deaths | 68 | 280 |
# | Max Cases per 100K | 50.55 | 1222.97 |
# | Max Deaths per 100K | 3.27 | 17.11 |

# %% [markdown]
# ### WA State (cases and deaths per 100K)

# %%
map_state(101, 'WA', wa_counties, confirmed_wa, 1, 60, deaths_wa, 1, 5)
# Out:
# <div id="altair-viz-dc0409eba22d4c7ebef8b810fd5345cb"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-dc0409eba22d4c7ebef8b810fd5345cb") {
#       outputDiv = document.getElementById("altair-viz-dc0409eba22d4c7ebef8b810fd5345cb");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/WA-53-washington-counties.json", "format": {"feature": "cb_2015_washington_county_20m", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "white", "stroke": "lightgray"}, "height": 600, "projection": {"type": "mercator"}, "width": 800}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": "geoshape", "encoding": {"color": {"type": "quantitative", "field": "confirmed_per100K", "scale": {"domain": [1, 60], "type": "log"}, "title": "Confirmed per 100K"}, "tooltip": [{"type": "ordinal", "field": "fips"}, {"type": "quantitative", "field": "confirmed"}, {"type": "quantitative", "field": "confirmed_per100K"}, {"type": "nominal", "field": "county"}, {"type": "nominal", "field": "date"}]}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-1f00375fdc9b2f0674bfc2cb8e726e3a"}, "key": "fips", "fields": ["confirmed_per100K", "confirmed", "county", "date", "fips"]}}]}, {"data": {"name": "data-d751713988987e9331980363e24189ce"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "aggregate": "sum", "field": "deaths_per100K", "scale": {"domain": [1, 5], "type": "symlog"}, "title": "Deaths per 100K"}, "stroke": {"value": "brown"}, "tooltip": [{"type": "quantitative", "field": "lat"}, {"type": "quantitative", "field": "long_"}, {"type": "quantitative", "field": "deaths"}, {"type": "nominal", "field": "county"}, {"type": "nominal", "field": "date"}]}, "title": "COVID-19 WA Confirmed Cases and Deaths per 100K by County [101, 2020-03-07]"}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-1f00375fdc9b2f0674bfc2cb8e726e3a": [{"fips": 53061, "day_num": 101, "date": "2020-03-07", "confirmed": 26, "confirmed_per100K": 3, "county": "Snohomish"}, {"fips": 53007, "day_num": 101, "date": "2020-03-07", "confirmed": 1, "confirmed_per100K": 1, "county": "Chelan"}, {"fips": 53033, "day_num": 101, "date": "2020-03-07", "confirmed": 72, "confirmed_per100K": 3, "county": "King"}, {"fips": 53037, "day_num": 101, "date": "2020-03-07", "confirmed": 1, "confirmed_per100K": 2, "county": "Kittitas"}, {"fips": 53031, "day_num": 101, "date": "2020-03-07", "confirmed": 1, "confirmed_per100K": 3, "county": "Jefferson"}, {"fips": 53071, "day_num": 101, "date": "2020-03-07", "confirmed": 1, "confirmed_per100K": 1, "county": "Walla Walla"}], "data-d751713988987e9331980363e24189ce": []}}, {"mode": "vega-lite"});
# </script>

# %%
map_state(107, 'WA', wa_counties, confirmed_wa, 1, 60, deaths_wa, 1, 5)
# Out:
# <div id="altair-viz-a8781cbf1e1345a98a0f46bc7419d401"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-a8781cbf1e1345a98a0f46bc7419d401") {
#       outputDiv = document.getElementById("altair-viz-a8781cbf1e1345a98a0f46bc7419d401");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/WA-53-washington-counties.json", "format": {"feature": "cb_2015_washington_county_20m", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "white", "stroke": "lightgray"}, "height": 600, "projection": {"type": "mercator"}, "width": 800}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": "geoshape", "encoding": {"color": {"type": "quantitative", "field": "confirmed_per100K", "scale": {"domain": [1, 60], "type": "log"}, "title": "Confirmed per 100K"}, "tooltip": [{"type": "ordinal", "field": "fips"}, {"type": "quantitative", "field": "confirmed"}, {"type": "quantitative", "field": "confirmed_per100K"}, {"type": "nominal", "field": "county"}, {"type": "nominal", "field": "date"}]}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-23234677fbdd370a47630c3b1979a58b"}, "key": "fips", "fields": ["confirmed_per100K", "confirmed", "county", "date", "fips"]}}]}, {"data": {"name": "data-136cd802297fe88bbbf63f7f772d398d"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "aggregate": "sum", "field": "deaths_per100K", "scale": {"domain": [1, 5], "type": "symlog"}, "title": "Deaths per 100K"}, "stroke": {"value": "brown"}, "tooltip": [{"type": "quantitative", "field": "lat"}, {"type": "quantitative", "field": "long_"}, {"type": "quantitative", "field": "deaths"}, {"type": "nominal", "field": "county"}, {"type": "nominal", "field": "date"}]}, "title": "COVID-19 WA Confirmed Cases and Deaths per 100K by County [107, 2020-03-07]"}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-23234677fbdd370a47630c3b1979a58b": [{"fips": 53061, "day_num": 107, "date": "2020-03-13", "confirmed": 132, "confirmed_per100K": 16, "county": "Snohomish"}, {"fips": 53031, "day_num": 107, "date": "2020-03-13", "confirmed": 1, "confirmed_per100K": 3, "county": "Jefferson"}, {"fips": 53025, "day_num": 107, "date": "2020-03-13", "confirmed": 1, "confirmed_per100K": 1, "county": "Grant"}, {"fips": 53013, "day_num": 107, "date": "2020-03-13", "confirmed": 1, "confirmed_per100K": 25, "county": "Columbia"}, {"fips": 53035, "day_num": 107, "date": "2020-03-13", "confirmed": 3, "confirmed_per100K": 1, "county": "Kitsap"}, {"fips": 53029, "day_num": 107, "date": "2020-03-13", "confirmed": 3, "confirmed_per100K": 3, "county": "Island"}, {"fips": 53057, "day_num": 107, "date": "2020-03-13", "confirmed": 3, "confirmed_per100K": 2, "county": "Skagit"}, {"fips": 53007, "day_num": 107, "date": "2020-03-13", "confirmed": 1, "confirmed_per100K": 1, "county": "Chelan"}, {"fips": 53033, "day_num": 107, "date": "2020-03-13", "confirmed": 329, "confirmed_per100K": 14, "county": "King"}, {"fips": 53027, "day_num": 107, "date": "2020-03-13", "confirmed": 1, "confirmed_per100K": 1, "county": "Grays Harbor"}, {"fips": 53067, "day_num": 107, "date": "2020-03-13", "confirmed": 3, "confirmed_per100K": 1, "county": "Thurston"}, {"fips": 53053, "day_num": 107, "date": "2020-03-13", "confirmed": 19, "confirmed_per100K": 2, "county": "Pierce"}, {"fips": 53037, "day_num": 107, "date": "2020-03-13", "confirmed": 3, "confirmed_per100K": 6, "county": "Kittitas"}, {"fips": 53071, "day_num": 107, "date": "2020-03-13", "confirmed": 1, "confirmed_per100K": 1, "county": "Walla Walla"}], "data-136cd802297fe88bbbf63f7f772d398d": [{"lat": 47.8691, "long_": -120.6188, "day_num": 107, "date": "2020-03-13", "deaths": 1, "deaths_per100K": 1, "county": "Chelan"}, {"lat": 47.4902, "long_": -121.8048, "day_num": 107, "date": "2020-03-13", "deaths": 33, "deaths_per100K": 1, "county": "King"}]}}, { ...
# </script>

# %%
map_state(114, 'WA', wa_counties, confirmed_wa, 1, 60, deaths_wa, 1, 5)
# Out:
# <div id="altair-viz-c245300239f0455f9f941a7d3d5642b0"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-c245300239f0455f9f941a7d3d5642b0") {
#       outputDiv = document.getElementById("altair-viz-c245300239f0455f9f941a7d3d5642b0");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/WA-53-washington-counties.json", "format": {"feature": "cb_2015_washington_county_20m", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "white", "stroke": "lightgray"}, "height": 600, "projection": {"type": "mercator"}, "width": 800}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": "geoshape", "encoding": {"color": {"type": "quantitative", "field": "confirmed_per100K", "scale": {"domain": [1, 60], "type": "log"}, "title": "Confirmed per 100K"}, "tooltip": [{"type": "ordinal", "field": "fips"}, {"type": "quantitative", "field": "confirmed"}, {"type": "quantitative", "field": "confirmed_per100K"}, {"type": "nominal", "field": "county"}, {"type": "nominal", "field": "date"}]}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-f0399e4311439c95895d1a925b2f6706"}, "key": "fips", "fields": ["confirmed_per100K", "confirmed", "county", "date", "fips"]}}]}, {"data": {"name": "data-1191b0823261ece9f2c31e3e6a326583"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "aggregate": "sum", "field": "deaths_per100K", "scale": {"domain": [1, 5], "type": "symlog"}, "title": "Deaths per 100K"}, "stroke": {"value": "brown"}, "tooltip": [{"type": "quantitative", "field": "lat"}, {"type": "quantitative", "field": "long_"}, {"type": "quantitative", "field": "deaths"}, {"type": "nominal", "field": "county"}, {"type": "nominal", "field": "date"}]}, "title": "COVID-19 WA Confirmed Cases and Deaths per 100K by County [114, 2020-03-07]"}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-f0399e4311439c95895d1a925b2f6706": [{"fips": 53027, "day_num": 114, "date": "2020-03-20", "confirmed": 1, "confirmed_per100K": 1, "county": "Grays Harbor"}, {"fips": 53037, "day_num": 114, "date": "2020-03-20", "confirmed": 4, "confirmed_per100K": 8, "county": "Kittitas"}, {"fips": 53065, "day_num": 114, "date": "2020-03-20", "confirmed": 1, "confirmed_per100K": 2, "county": "Stevens"}, {"fips": 53029, "day_num": 114, "date": "2020-03-20", "confirmed": 19, "confirmed_per100K": 22, "county": "Island"}, {"fips": 53013, "day_num": 114, "date": "2020-03-20", "confirmed": 1, "confirmed_per100K": 25, "county": "Columbia"}, {"fips": 53005, "day_num": 114, "date": "2020-03-20", "confirmed": 3, "confirmed_per100K": 1, "county": "Benton"}, {"fips": 53057, "day_num": 114, "date": "2020-03-20", "confirmed": 26, "confirmed_per100K": 20, "county": "Skagit"}, {"fips": 53067, "day_num": 114, "date": "2020-03-20", "confirmed": 8, "confirmed_per100K": 2, "county": "Thurston"}, {"fips": 53063, "day_num": 114, "date": "2020-03-20", "confirmed": 11, "confirmed_per100K": 2, "county": "Spokane"}, {"fips": 53025, "day_num": 114, "date": "2020-03-20", "confirmed": 11, "confirmed_per100K": 11, "county": "Grant"}, {"fips": 53009, "day_num": 114, "date": "2020-03-20", "confirmed": 1, "confirmed_per100K": 1, "county": "Clallam"}, {"fips": 53035, "day_num": 114, "date": "2020-03-20", "confirmed": 12, "confirmed_per100K": 4, "county": "Kitsap"}, {"fips": 53007, "day_num": 114, "date": "2020-03-20", "confirmed": 3, "confirmed_per100K": 3, "county": "Chelan"}, {"fips": 53073, "day_num": 114, "date": "2020-03-20", "confirmed": 11, "confirmed_per100K": 4, "county": "Whatcom"}, {"fips": 53055, "day_num": 114, "date": "2020-03-20", "confirmed": 1, "confirmed_per100K": 5, "county": "San Juan"}, {"fips": 53015, "day_num": 114, "date": "2020-03-20", "confirmed": 2, "confirmed_per100K": 1, "county": "Cowlitz"}, {"fips": 53021, "day_num": 114, "date": "2020-03-20", "confirmed": 1, "confi ...
# </script>

# %% [markdown]
# ### NY State (cases and deaths per 100K)

# %%
map_state(101, 'NY', ny_counties, confirmed_ny, 1, 1500, deaths_ny, 1, 20)
# Out:
# <div id="altair-viz-ec9d48984cbb44f3b2e8df88218ad27d"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-ec9d48984cbb44f3b2e8df88218ad27d") {
#       outputDiv = document.getElementById("altair-viz-ec9d48984cbb44f3b2e8df88218ad27d");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/NY-36-new-york-counties.json", "format": {"feature": "cb_2015_new_york_county_20m", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "white", "stroke": "lightgray"}, "height": 600, "projection": {"type": "mercator"}, "width": 800}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": "geoshape", "encoding": {"color": {"type": "quantitative", "field": "confirmed_per100K", "scale": {"domain": [1, 1500], "type": "log"}, "title": "Confirmed per 100K"}, "tooltip": [{"type": "ordinal", "field": "fips"}, {"type": "quantitative", "field": "confirmed"}, {"type": "quantitative", "field": "confirmed_per100K"}, {"type": "nominal", "field": "county"}, {"type": "nominal", "field": "date"}]}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-517d33f19e7ae2ee69fba056b7a56c1a"}, "key": "fips", "fields": ["confirmed_per100K", "confirmed", "county", "date", "fips"]}}]}, {"data": {"name": "data-d751713988987e9331980363e24189ce"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "aggregate": "sum", "field": "deaths_per100K", "scale": {"domain": [1, 20], "type": "symlog"}, "title": "Deaths per 100K"}, "stroke": {"value": "brown"}, "tooltip": [{"type": "quantitative", "field": "lat"}, {"type": "quantitative", "field": "long_"}, {"type": "quantitative", "field": "deaths"}, {"type": "nominal", "field": "county"}, {"type": "nominal", "field": "date"}]}, "title": "COVID-19 NY Confirmed Cases and Deaths per 100K by County [101, 2020-03-12]"}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-517d33f19e7ae2ee69fba056b7a56c1a": [{"fips": 36111, "day_num": 101, "date": "2020-03-12", "confirmed": 4, "confirmed_per100K": 2, "county": "Ulster"}, {"fips": 36103, "day_num": 101, "date": "2020-03-12", "confirmed": 21, "confirmed_per100K": 1, "county": "Suffolk"}, {"fips": 36119, "day_num": 101, "date": "2020-03-12", "confirmed": 147, "confirmed_per100K": 15, "county": "Westchester"}, {"fips": 36025, "day_num": 101, "date": "2020-03-12", "confirmed": 1, "confirmed_per100K": 2, "county": "Delaware"}, {"fips": 36091, "day_num": 101, "date": "2020-03-12", "confirmed": 3, "confirmed_per100K": 1, "county": "Saratoga"}, {"fips": 36059, "day_num": 101, "date": "2020-03-12", "confirmed": 41, "confirmed_per100K": 3, "county": "Nassau"}, {"fips": 36087, "day_num": 101, "date": "2020-03-12", "confirmed": 7, "confirmed_per100K": 2, "county": "Rockland"}, {"fips": 36061, "day_num": 101, "date": "2020-03-12", "confirmed": 96, "confirmed_per100K": 5, "county": "New York City"}, {"fips": 36043, "day_num": 101, "date": "2020-03-12", "confirmed": 1, "confirmed_per100K": 1, "county": "Herkimer"}], "data-d751713988987e9331980363e24189ce": []}}, {"mode": "vega-lite"});
# </script>

# %%
map_state(107, 'NY', ny_counties, confirmed_ny, 1, 1500, deaths_ny, 1, 20)
# Out:
# <div id="altair-viz-e0f84b40c3224e4587d9cdfba7a119ba"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-e0f84b40c3224e4587d9cdfba7a119ba") {
#       outputDiv = document.getElementById("altair-viz-e0f84b40c3224e4587d9cdfba7a119ba");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/NY-36-new-york-counties.json", "format": {"feature": "cb_2015_new_york_county_20m", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "white", "stroke": "lightgray"}, "height": 600, "projection": {"type": "mercator"}, "width": 800}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": "geoshape", "encoding": {"color": {"type": "quantitative", "field": "confirmed_per100K", "scale": {"domain": [1, 1500], "type": "log"}, "title": "Confirmed per 100K"}, "tooltip": [{"type": "ordinal", "field": "fips"}, {"type": "quantitative", "field": "confirmed"}, {"type": "quantitative", "field": "confirmed_per100K"}, {"type": "nominal", "field": "county"}, {"type": "nominal", "field": "date"}]}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-7c966b6738801cc30ab586bb7a408547"}, "key": "fips", "fields": ["confirmed_per100K", "confirmed", "county", "date", "fips"]}}]}, {"data": {"name": "data-5127f518bed2a39a00f0e4b005fa4e21"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "aggregate": "sum", "field": "deaths_per100K", "scale": {"domain": [1, 20], "type": "symlog"}, "title": "Deaths per 100K"}, "stroke": {"value": "brown"}, "tooltip": [{"type": "quantitative", "field": "lat"}, {"type": "quantitative", "field": "long_"}, {"type": "quantitative", "field": "deaths"}, {"type": "nominal", "field": "county"}, {"type": "nominal", "field": "date"}]}, "title": "COVID-19 NY Confirmed Cases and Deaths per 100K by County [107, 2020-03-12]"}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-7c966b6738801cc30ab586bb7a408547": [{"fips": 36059, "day_num": 107, "date": "2020-03-18", "confirmed": 183, "confirmed_per100K": 13, "county": "Nassau"}, {"fips": 36093, "day_num": 107, "date": "2020-03-18", "confirmed": 14, "confirmed_per100K": 9, "county": "Schenectady"}, {"fips": 36119, "day_num": 107, "date": "2020-03-18", "confirmed": 537, "confirmed_per100K": 55, "county": "Westchester"}, {"fips": 36091, "day_num": 107, "date": "2020-03-18", "confirmed": 14, "confirmed_per100K": 6, "county": "Saratoga"}, {"fips": 36103, "day_num": 107, "date": "2020-03-18", "confirmed": 116, "confirmed_per100K": 7, "county": "Suffolk"}, {"fips": 36043, "day_num": 107, "date": "2020-03-18", "confirmed": 1, "confirmed_per100K": 1, "county": "Herkimer"}, {"fips": 36061, "day_num": 107, "date": "2020-03-18", "confirmed": 1339, "confirmed_per100K": 82, "county": "New York City"}, {"fips": 36113, "day_num": 107, "date": "2020-03-18", "confirmed": 1, "confirmed_per100K": 1, "county": "Warren"}, {"fips": 36027, "day_num": 107, "date": "2020-03-18", "confirmed": 20, "confirmed_per100K": 6, "county": "Dutchess"}, {"fips": 36057, "day_num": 107, "date": "2020-03-18", "confirmed": 1, "confirmed_per100K": 2, "county": "Montgomery"}, {"fips": 36105, "day_num": 107, "date": "2020-03-18", "confirmed": 1, "confirmed_per100K": 1, "county": "Sullivan"}, {"fips": 36111, "day_num": 107, "date": "2020-03-18", "confirmed": 9, "confirmed_per100K": 5, "county": "Ulster"}, {"fips": 36025, "day_num": 107, "date": "2020-03-18", "confirmed": 1, "confirmed_per100K": 2, "county": "Delaware"}, {"fips": 36041, "day_num": 107, "date": "2020-03-18", "confirmed": 1, "confirmed_per100K": 22, "county": "Hamilton"}, {"fips": 36083, "day_num": 107, "date": "2020-03-18", "confirmed": 4, "confirmed_per100K": 2, "county": "Rensselaer"}, {"fips": 36019, "day_num": 107, "date": "2020-03-18", "confirmed": 1, "confirmed_per100K": 1, "county": "Clinton"}, {"fips": 36115, "day_num": 107, "date": "2020-03-1 ...
# </script>

# %%
map_state(114, 'NY', ny_counties, confirmed_ny, 1, 1500, deaths_ny, 1, 20)
# Out:
# <div id="altair-viz-be10574eac72402f8ed6b438b3384b2b"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-be10574eac72402f8ed6b438b3384b2b") {
#       outputDiv = document.getElementById("altair-viz-be10574eac72402f8ed6b438b3384b2b");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/NY-36-new-york-counties.json", "format": {"feature": "cb_2015_new_york_county_20m", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "white", "stroke": "lightgray"}, "height": 600, "projection": {"type": "mercator"}, "width": 800}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": "geoshape", "encoding": {"color": {"type": "quantitative", "field": "confirmed_per100K", "scale": {"domain": [1, 1500], "type": "log"}, "title": "Confirmed per 100K"}, "tooltip": [{"type": "ordinal", "field": "fips"}, {"type": "quantitative", "field": "confirmed"}, {"type": "quantitative", "field": "confirmed_per100K"}, {"type": "nominal", "field": "county"}, {"type": "nominal", "field": "date"}]}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-70899256b736c4f9ec77929e4405f02c"}, "key": "fips", "fields": ["confirmed_per100K", "confirmed", "county", "date", "fips"]}}]}, {"data": {"name": "data-40e9f0cf8a048199388c6318a588fc7c"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "aggregate": "sum", "field": "deaths_per100K", "scale": {"domain": [1, 20], "type": "symlog"}, "title": "Deaths per 100K"}, "stroke": {"value": "brown"}, "tooltip": [{"type": "quantitative", "field": "lat"}, {"type": "quantitative", "field": "long_"}, {"type": "quantitative", "field": "deaths"}, {"type": "nominal", "field": "county"}, {"type": "nominal", "field": "date"}]}, "title": "COVID-19 NY Confirmed Cases and Deaths per 100K by County [114, 2020-03-12]"}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-70899256b736c4f9ec77929e4405f02c": [{"fips": 36093, "day_num": 114, "date": "2020-03-25", "confirmed": 55, "confirmed_per100K": 35, "county": "Schenectady"}, {"fips": 36001, "day_num": 114, "date": "2020-03-25", "confirmed": 152, "confirmed_per100K": 49, "county": "Albany"}, {"fips": 36117, "day_num": 114, "date": "2020-03-25", "confirmed": 7, "confirmed_per100K": 7, "county": "Wayne"}, {"fips": 36071, "day_num": 114, "date": "2020-03-25", "confirmed": 638, "confirmed_per100K": 165, "county": "Orange"}, {"fips": 36025, "day_num": 114, "date": "2020-03-25", "confirmed": 5, "confirmed_per100K": 11, "county": "Delaware"}, {"fips": 36011, "day_num": 114, "date": "2020-03-25", "confirmed": 2, "confirmed_per100K": 2, "county": "Cayuga"}, {"fips": 36055, "day_num": 114, "date": "2020-03-25", "confirmed": 118, "confirmed_per100K": 15, "county": "Monroe"}, {"fips": 36087, "day_num": 114, "date": "2020-03-25", "confirmed": 1069, "confirmed_per100K": 328, "county": "Rockland"}, {"fips": 36119, "day_num": 114, "date": "2020-03-25", "confirmed": 4691, "confirmed_per100K": 484, "county": "Westchester"}, {"fips": 36033, "day_num": 114, "date": "2020-03-25", "confirmed": 1, "confirmed_per100K": 1, "county": "Franklin"}, {"fips": 36003, "day_num": 114, "date": "2020-03-25", "confirmed": 2, "confirmed_per100K": 4, "county": "Allegany"}, {"fips": 36043, "day_num": 114, "date": "2020-03-25", "confirmed": 5, "confirmed_per100K": 8, "county": "Herkimer"}, {"fips": 36017, "day_num": 114, "date": "2020-03-25", "confirmed": 3, "confirmed_per100K": 6, "county": "Chenango"}, {"fips": 36029, "day_num": 114, "date": "2020-03-25", "confirmed": 122, "confirmed_per100K": 13, "county": "Erie"}, {"fips": 36113, "day_num": 114, "date": "2020-03-25", "confirmed": 2, "confirmed_per100K": 3, "county": "Warren"}, {"fips": 36057, "day_num": 114, "date": "2020-03-25", "confirmed": 4, "confirmed_per100K": 8, "county": "Montgomery"}, {"fips": 36079, "day_num": 114, "date": "2020-03-25", "c ...

# %% [markdown]
# ## COVID-19 Confirmed Cases and Deaths by WA and NY County Slider

# %%
# State Choropleth Map Visualization Function
def map_state_slider(state_txt, state_counties, confirmed, confirmed_min, confirmed_max, deaths, deaths_min, deaths_max, state_fips):
  # Pivot confirmed data by day_num
  confirmed_pv = confirmed[['fips', 'day_num', 'confirmed']].copy()
  confirmed_pv['fips'] = confirmed_pv['fips'].astype(str)
  confirmed_pv['day_num'] = confirmed_pv['day_num'].astype(str)
  confirmed_pv['confirmed'] = confirmed_pv['confirmed'].astype('int64')
  confirmed_pv = confirmed_pv.pivot_table(index='fips', columns='day_num', values='confirmed', fill_value=0).reset_index()

  # Pivot deaths data by day_num
  deaths_pv = deaths[['lat', 'long_', 'day_num', 'deaths']].copy()
  deaths_pv['day_num'] = deaths_pv['day_num'].astype(str)
  deaths_pv['deaths'] = deaths_pv['deaths'].astype('int64')
  deaths_pv = deaths_pv.pivot_table(index=['lat', 'long_'], columns='day_num', values='deaths', fill_value=0).reset_index()

  # Extract column names for slider
  column_names = confirmed_pv.columns.tolist()

  # Remove first element (`fips`)
  column_names.pop(0)

  # Convert to int
  column_values = [None] * len(column_names)
  for i in range(0, len(column_names)): column_values[i] = int(column_names[i]) 
  
  # Disable max_rows to see more data
  alt.data_transformers.disable_max_rows()

  # Topographic information
  us_states = alt.topo_feature(topo_usa, 'states')
  us_counties = alt.topo_feature(topo_usa, 'counties')

  # state county boundaries
  base_state = alt.Chart(state_counties).mark_geoshape(
      fill='white',
      stroke='lightgray',
  ).properties(
      width=800,
      height=600,
  ).project(
      type='mercator'
  )

  # Slider choices
  min_day_num = column_values[0]
  max_day_num = column_values[len(column_values)-1]
  slider = alt.binding_range(min=min_day_num, max=max_day_num, step=1)
  slider_selection = alt.selection_single(fields=['day_num'], bind=slider, name="day_num", init={'day_num':min_day_num})


  # Confirmed cases by county
  base_state_counties = alt.Chart(us_counties).mark_geoshape(
      stroke='black',
      strokeWidth=0.05
  ).transform_lookup(
      lookup='id',
      from_=alt.LookupData(confirmed_pv, 'fips', column_names)  
  ).transform_fold(
      column_names, as_=['day_num', 'confirmed']
  ).transform_calculate(
      state_id = "(datum.id / 1000)|0",
      day_num = 'parseInt(datum.day_num)',
      confirmed = 'isValid(datum.confirmed) ? datum.confirmed : -1'
  ).encode(
      color = alt.condition(
          'datum.confirmed > 0',      
          alt.Color('confirmed:Q', scale=alt.Scale(domain=(confirmed_min, confirmed_max), type='symlog')),
          alt.value('white')
        )  
  ).properties(
    # update figure title
    title=f'COVID-19 WA State Confirmed Cases by County'
  ).transform_filter(
      (alt.datum.state_id)==state_fips
  ).transform_filter(
      slider_selection
  )

  # deaths by long, latitude
  points = alt.Chart(
    deaths_pv
  ).mark_point(
    opacity=0.75, filled=True
  ).transform_fold(
    column_names, as_=['day_num', 'deaths']
  ).transform_calculate(
      day_num = 'parseInt(datum.day_num)',
      deaths = 'isValid(datum.deaths) ? datum.deaths : -1'  
  ).encode(
    longitude='long_:Q',
    latitude='lat:Q',
    size=alt.Size('deaths:Q', scale=alt.Scale(domain=(deaths_min, deaths_max), type='symlog'), title='deaths'),
    color=alt.value('#BD595D'),
    stroke=alt.value('brown'),
  ).add_selection(
      slider_selection
  ).transform_filter(
      slider_selection
  )

  # confirmed cases (base_counties) and deaths (points)
  return (base_state + base_state_counties + points)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# | Factors | WA | NY |
# | ------- | -- | -- |
# | Educational Facilities Closed | 3/13/2020 | 3/18/2020 |
# | Day 00 | 3/6/2020 | 3/11/2020 |
# | Day 14 | 3/20/2020 | 3/25/2020 |
# | Max Cases | 794 | 20011 |
# | Max Deaths | 68 | 280 |
# | Max Cases per 100K | 50.55 | 1222.97 |
# | Max Deaths per 100K | 3.27 | 17.11 |

# %%
map_state_slider('WA', wa_counties, confirmed_wa, 1, 800, deaths_wa, 1, 70, 53)
# Out:
# <div id="altair-viz-8df55296e0ae4eb5a0ab14b3b864c106"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-8df55296e0ae4eb5a0ab14b3b864c106") {
#       outputDiv = document.getElementById("altair-viz-8df55296e0ae4eb5a0ab14b3b864c106");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/WA-53-washington-counties.json", "format": {"feature": "cb_2015_washington_county_20m", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "white", "stroke": "lightgray"}, "height": 600, "projection": {"type": "mercator"}, "width": 800}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": {"type": "geoshape", "stroke": "black", "strokeWidth": 0.05}, "encoding": {"color": {"condition": {"type": "quantitative", "field": "confirmed", "scale": {"domain": [1, 800], "type": "symlog"}, "test": "datum.confirmed > 0"}, "value": "white"}}, "title": "COVID-19 WA State Confirmed Cases by County", "transform": [{"lookup": "id", "from": {"data": {"name": "data-b50d3fc94ca28b3ff4c2f4be50f93342"}, "key": "fips", "fields": ["101", "102", "103", "104", "105", "106", "107", "108", "109", "110", "111", "112", "113", "114"]}}, {"fold": ["101", "102", "103", "104", "105", "106", "107", "108", "109", "110", "111", "112", "113", "114"], "as": ["day_num", "confirmed"]}, {"calculate": "(datum.id / 1000)|0", "as": "state_id"}, {"calculate": "parseInt(datum.day_num)", "as": "day_num"}, {"calculate": "isValid(datum.confirmed) ? datum.confirmed : -1", "as": "confirmed"}, {"filter": "(datum.state_id === 53)"}, {"filter": {"selection": "day_num"}}]}, {"data": {"name": "data-eca1fcc3548d66714bb4238a74c6f34c"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "field": "deaths", "scale": {"domain": [1, 70], "type": "symlog"}, "title": "deaths"}, "stroke": {"value": "brown"}}, "selection": {"day_num": {"type": "single", "fields": ["day_num"], "bind": {"input": "range", "max": 114, "min": 101, "step": 1}, "init": {"day_num": 101}}}, "transform": [{"fold": ["101", "102", "103", "104", "105", "106", "107", "108", "109", "110", "111", "112", "113", "114"], "as": ["day_num",
"101": 0, "102": 0, "103": 0, "104": 0, "105": 0, "106": 1, "107": 1, "108": 1, "109": 2, "110": 4, "111": 4, "112": 6, "113": 8, "114": 10}, {"fips": "36021", "101": 0, "102": 0, "103": 0, "104": 0, "105": 0, "106": 0, "107": 0, "108": 0, "109": 1, "110": 2, "111": 5, "112": 10, "113": 11, "114": 1 ...

# %% [markdown]
# ## COVID-19 Confirmed Cases and Deaths by WA and NY County Map and Graph

# %%
# map_state_graph
def map_state_graph(state_txt, state_counties, confirmed, confirmed_min, confirmed_max, deaths, deaths_min, deaths_max, state_fips):
  
  # pivot confirmed cases (by date)
  confirmed_pv2 = confirmed[['fips', 'date', 'confirmed']].copy()
  confirmed_pv2['fips'] = confirmed_pv2['fips'].astype(str)
  confirmed_pv2['date'] = confirmed_pv2['date'].astype(str)
  confirmed_pv2['confirmed'] = confirmed_pv2['confirmed'].astype('int64')
  confirmed_pv2 = confirmed_pv2.pivot_table(index='fips', columns='date', values='confirmed', fill_value=0).reset_index()

  # pivot deaths
  deaths_pv2 = deaths[['lat', 'long_', 'date', 'deaths']].copy()
  deaths_pv2['date'] = deaths_pv2['date'].astype(str)
  deaths_pv2['deaths'] = deaths_pv2['deaths'].astype('int64')
  deaths_pv2 = deaths_pv2.pivot_table(index=['lat', 'long_'], columns='date', values='deaths', fill_value=0).reset_index()

  # Extract column names for slider
  column_names2 = confirmed_pv2.columns.tolist()

  # Remove first element (`fips`)
  column_names2.pop(0)

  # date selection
  pts = alt.selection(type="single", encodings=['x'])

  # State
  base_state = alt.Chart(state_counties).mark_geoshape(
      fill='white',
      stroke='lightgray',
  ).properties(
      width=800,
      height=600,
  ).project(
      type='mercator'
  )

  # State Counties
  base_state_counties = alt.Chart(us_counties).mark_geoshape(
    stroke='black',
    strokeWidth=0.05,
  ).transform_lookup(
    lookup='id',
   from_=alt.LookupData(confirmed_pv2, 'fips', column_names2)
   ).transform_fold(
     column_names2, as_=['date', 'confirmed']
  ).transform_calculate(
      state_id = "(datum.id / 1000)|0",
      date = 'datum.date',
      confirmed = 'isValid(datum.confirmed) ? datum.confirmed : -1'
  ).encode(
       color = alt.condition(
          'datum.confirmed > 0',      
          alt.Color('confirmed:Q', scale=alt.Scale(domain=(confirmed_min, confirmed_max), type='symlog')),
          alt.value('white')
        )  
  ).transform_filter(
    pts
  ).transform_filter(
      (alt.datum.state_id)==state_fips
  )

  # Bar Graph
  bar = alt.Chart(confirmed).mark_bar().encode(
      x='date:N',
      y='confirmed_per100K:Q',
      color=alt.condition(pts, alt.ColorValue("steelblue"), alt.ColorValue("grey"))
  ).properties(
      width=800,
      height=200,
      title='Confirmed Cases per 100K'
  ).add_selection(pts)

  # Deaths
  points = alt.Chart(deaths).mark_point(opacity=0.75, filled=True).encode(
    longitude='long_:Q',
    latitude='lat:Q',
    size=alt.Size('sum(deaths):Q', scale=alt.Scale(domain=[deaths_min, deaths_max]), title='Deaths'),
    color=alt.value('#BD595D'),
    stroke=alt.value('brown'),
    tooltip=[
      alt.Tooltip('lat'),
      alt.Tooltip('long_'),
      alt.Tooltip('deaths'),
      alt.Tooltip('county:N'),      
      alt.Tooltip('date:N'),      
    ],
  ).properties(
    # update figure title
    title=f'COVID-19 Confirmed Cases and Deaths by County'
  ).transform_filter(
      pts
  )

  return (base_state + base_state_counties + points) & bar
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
map_state_graph('WA', wa_counties, confirmed_wa, 1, 800, deaths_wa, 1, 70, 53)
# Out:
# <div id="altair-viz-c58002f5d63e44daad09932a907035fa"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-c58002f5d63e44daad09932a907035fa") {
#       outputDiv = document.getElementById("altair-viz-c58002f5d63e44daad09932a907035fa");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "vconcat": [{"layer": [{"data": {"url": "https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/WA-53-washington-counties.json", "format": {"feature": "cb_2015_washington_county_20m", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "white", "stroke": "lightgray"}, "height": 600, "projection": {"type": "mercator"}, "width": 800}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": {"type": "geoshape", "stroke": "black", "strokeWidth": 0.05}, "encoding": {"color": {"condition": {"type": "quantitative", "field": "confirmed", "scale": {"domain": [1, 800], "type": "symlog"}, "test": "datum.confirmed > 0"}, "value": "white"}}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-2bd44bbb3427f2157c60a38d85f6edcc"}, "key": "fips", "fields": ["2020-03-07", "2020-03-08", "2020-03-09", "2020-03-10", "2020-03-11", "2020-03-12", "2020-03-13", "2020-03-14", "2020-03-15", "2020-03-16", "2020-03-17", "2020-03-18", "2020-03-19", "2020-03-20"]}}, {"fold": ["2020-03-07", "2020-03-08", "2020-03-09", "2020-03-10", "2020-03-11", "2020-03-12", "2020-03-13", "2020-03-14", "2020-03-15", "2020-03-16", "2020-03-17", "2020-03-18", "2020-03-19", "2020-03-20"], "as": ["date", "confirmed"]}, {"calculate": "(datum.id / 1000)|0", "as": "state_id"}, {"calculate": "datum.date", "as": "date"}, {"calculate": "isValid(datum.confirmed) ? datum.confirmed : -1", "as": "confirmed"}, {"filter": {"selection": "selector001"}}, {"filter": "(datum.state_id === 53)"}]}, {"data": {"name": "data-6842c9da8bb5ab8169ea546a9dae984c"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "aggregate": "sum", "field": "deaths", "scale": {"domain": [1, 70]}, "title": "Deaths"}, "stroke": {"value": "brown"}, "tooltip": [{"type": "quantitative", "field": "lat"}, {"type": "quantitative", "field": "long_"}, {"type": "quantitative", "field": "deaths"}, {"type": "nominal", "field": "county"}, {"type": "nominal", "field": "date"}]}, "title": "COVID-19 Confirmed Cases and Deaths by County", "transform": [{"filter": {"selection": "selector001"}}]}]}, {"data": {"name": "data-097a1ffc3f1241fe8543ebc9e211405a"}, "mark": "bar", "encoding": {"color": {"condition": {"value": "steelblue", "selection": "selector001"}, "value": "grey"}, "x": {"type": "nominal", "field": "date"}, "y": {"type": "quantitative", "field": "confirmed_per100K"}}, "height": 200, "selection": {"selector001": {"type": "single", "encodings": ["x"]}}, "title": "Confirmed Cases per 100K", "width": 800}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-2bd44bbb3427f2157c60a38d85f6edcc": [{"fips": "53005", "2020-03-07": 0, "2020-03-08": 0, "2020-03-09": 0, "2020-03-10": 0, "2020-03-11": 0, "2020-03-12": 0, "2020-03-13": 0, "2020-03-14": 0, "2020-03-15": 0, "2020-03-16": 0, "2020-03-17": 0, "2020-03-18": 1, "2020-03-19": 2, "2020-03-20": 3}, {"fips": "53007", "2020-03-07": 1, "2020-03-08": 1, "2020-03-09": 1, "2020-03-10": 1, "2020-03-11": 1, "2020-03-12": 1, "2020-03-13": 1, "2020-03-14": 1, "2020-03-15": 1, "2020-03-16": 1, "2020-03-17": 3, "2020-03-18": 3, "2020-03-19": 3, "2020-03-20": 3}, {"fips": "53009", "2020-03-07": 0, "2020-03-08": 0, "2020-03-09": 0, "2020-03-10": 0, "2020-03-11": 0, "2020-03-12": 0, "2020-03-13": 0, "2020-03-14": 0, "2020-03-15": 0, "2020-03-16": 0, "2020-03-17": 0, "2020-03-18": 0, "2020-03-19": 1, "2020-03-20": 1}, {"fips": "53011", "2020-03-07": 1, "2020-03-08": 1, "2020-03-09": 1, "2020-03-10": 1, "2020-03-11": 1, "2020-03-12": 1, "2020-03-13": 3, "2020-03-14": 3, "2020-03-15": 3, "2020-03-16": 4, "2020-03-17": 4, "2020-03-18": 4, "2020-03-19": 4, "2020-03-20": 6}, { ...

# %%
map_state_graph('NY', ny_counties, confirmed_ny, 1, 21000, deaths_ny, 1, 300, 36)
# Out:
# <div id="altair-viz-b2c6b005385549fbb219dbb35579ff44"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-b2c6b005385549fbb219dbb35579ff44") {
#       outputDiv = document.getElementById("altair-viz-b2c6b005385549fbb219dbb35579ff44");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "vconcat": [{"layer": [{"data": {"url": "https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/NY-36-new-york-counties.json", "format": {"feature": "cb_2015_new_york_county_20m", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "white", "stroke": "lightgray"}, "height": 600, "projection": {"type": "mercator"}, "width": 800}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": {"type": "geoshape", "stroke": "black", "strokeWidth": 0.05}, "encoding": {"color": {"condition": {"type": "quantitative", "field": "confirmed", "scale": {"domain": [1, 21000], "type": "symlog"}, "test": "datum.confirmed > 0"}, "value": "white"}}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-3ae0a5d466b1ceec481095fdbc53dd15"}, "key": "fips", "fields": ["2020-03-12", "2020-03-13", "2020-03-14", "2020-03-15", "2020-03-16", "2020-03-17", "2020-03-18", "2020-03-19", "2020-03-20", "2020-03-21", "2020-03-22", "2020-03-23", "2020-03-24", "2020-03-25"]}}, {"fold": ["2020-03-12", "2020-03-13", "2020-03-14", "2020-03-15", "2020-03-16", "2020-03-17", "2020-03-18", "2020-03-19", "2020-03-20", "2020-03-21", "2020-03-22", "2020-03-23", "2020-03-24", "2020-03-25"], "as": ["date", "confirmed"]}, {"calculate": "(datum.id / 1000)|0", "as": "state_id"}, {"calculate": "datum.date", "as": "date"}, {"calculate": "isValid(datum.confirmed) ? datum.confirmed : -1", "as": "confirmed"}, {"filter": {"selection": "selector002"}}, {"filter": "(datum.state_id === 36)"}]}, {"data": {"name": "data-5d015a4545cbe8265e58cdab55f0ebf6"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "aggregate": "sum", "field": "deaths", "scale": {"domain": [1, 300]}, "title": "Deaths"}, "stroke": {"value": "brown"}, "tooltip": [{"type": "quantitative", "field": "lat"}, {"type": "quantitative", "field": "long_"}, {"type": "quantitative", "field": "deaths"}, {"type": "nominal", "field": "county"}, {"type": "nominal", "field": "date"}]}, "title": "COVID-19 Confirmed Cases and Deaths by County", "transform": [{"filter": {"selection": "selector002"}}]}]}, {"data": {"name": "data-e7bbb5e734f07f205f6f1727c85af640"}, "mark": "bar", "encoding": {"color": {"condition": {"value": "steelblue", "selection": "selector002"}, "value": "grey"}, "x": {"type": "nominal", "field": "date"}, "y": {"type": "quantitative", "field": "confirmed_per100K"}}, "height": 200, "selection": {"selector002": {"type": "single", "encodings": ["x"]}}, "title": "Confirmed Cases per 100K", "width": 800}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-3ae0a5d466b1ceec481095fdbc53dd15": [{"fips": "36001", "2020-03-12": 2, "2020-03-13": 2, "2020-03-14": 5, "2020-03-15": 11, "2020-03-16": 12, "2020-03-17": 23, "2020-03-18": 36, "2020-03-19": 43, "2020-03-20": 61, "2020-03-21": 88, "2020-03-22": 123, "2020-03-23": 127, "2020-03-24": 146, "2020-03-25": 152}, {"fips": "36003", "2020-03-12": 0, "2020-03-13": 0, "2020-03-14": 0, "2020-03-15": 0, "2020-03-16": 2, "2020-03-17": 2, "2020-03-18": 2, "2020-03-19": 2, "2020-03-20": 2, "2020-03-21": 2, "2020-03-22": 2, "2020-03-23": 2, "2020-03-24": 2, "2020-03-25": 2}, {"fips": "36007", "2020-03-12": 0, "2020-03-13": 0, "2020-03-14": 1, "2020-03-15": 1, "2020-03-16": 1, "2020-03-17": 1, "2020-03-18": 2, "2020-03-19": 2, "2020-03-20": 2, "2020-03-21": 2, "2020-03-22": 3, "2020-03-23": 7, "2020-03-24": 9, "2020-03-25": 11}, {"fips": "36011", "2020-03-12": 0, "2020-03-13": 0, "2020-03-14": 0, "2020-03-15": 0, "2020-03-16": 0, "2020-03-17": 0, "2020-03-18": 0, "2020-03-19": 0, "2020-03-20": 0, "2020-03-21": 0, "2020-03-22": 0, "2020-03-23": 2, "2020-03-24": 2, "202 ...

# %%
map_state_graph('NY', ny_counties, confirmed_ny_m1, 1, 4500, deaths_ny, 1, 70, 36)
# Out:
# <div id="altair-viz-e91a97d013bd4443afbca1397609a93b"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-e91a97d013bd4443afbca1397609a93b") {
#       outputDiv = document.getElementById("altair-viz-e91a97d013bd4443afbca1397609a93b");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "vconcat": [{"layer": [{"data": {"url": "https://raw.githubusercontent.com/deldersveld/topojson/master/countries/us-states/NY-36-new-york-counties.json", "format": {"feature": "cb_2015_new_york_county_20m", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "white", "stroke": "lightgray"}, "height": 600, "projection": {"type": "mercator"}, "width": 800}, {"data": {"url": "https://vega.github.io/vega-datasets/data/us-10m.json", "format": {"feature": "counties", "type": "topojson"}}, "mark": {"type": "geoshape", "stroke": "black", "strokeWidth": 0.05}, "encoding": {"color": {"condition": {"type": "quantitative", "field": "confirmed", "scale": {"domain": [1, 4500], "type": "symlog"}, "test": "datum.confirmed > 0"}, "value": "white"}}, "transform": [{"lookup": "id", "from": {"data": {"name": "data-1cd5af0cac96245a3e05a86bb4ea5fc4"}, "key": "fips", "fields": ["2020-03-07", "2020-03-08", "2020-03-09", "2020-03-10", "2020-03-11", "2020-03-12", "2020-03-13", "2020-03-14", "2020-03-15", "2020-03-16", "2020-03-17", "2020-03-18", "2020-03-19", "2020-03-20"]}}, {"fold": ["2020-03-07", "2020-03-08", "2020-03-09", "2020-03-10", "2020-03-11", "2020-03-12", "2020-03-13", "2020-03-14", "2020-03-15", "2020-03-16", "2020-03-17", "2020-03-18", "2020-03-19", "2020-03-20"], "as": ["date", "confirmed"]}, {"calculate": "(datum.id / 1000)|0", "as": "state_id"}, {"calculate": "datum.date", "as": "date"}, {"calculate": "isValid(datum.confirmed) ? datum.confirmed : -1", "as": "confirmed"}, {"filter": {"selection": "selector194"}}, {"filter": "(datum.state_id === 36)"}]}, {"data": {"name": "data-5d015a4545cbe8265e58cdab55f0ebf6"}, "mark": {"type": "point", "filled": true, "opacity": 0.75}, "encoding": {"color": {"value": "#BD595D"}, "latitude": {"field": "lat", "type": "quantitative"}, "longitude": {"field": "long_", "type": "quantitative"}, "size": {"type": "quantitative", "aggregate": "sum", "field": "deaths", "scale": {"domain": [1, 70]}, "title": "Deaths"}, "stroke": {"value": "brown"}, "tooltip": [{"type": "quantitative", "field": "lat"}, {"type": "quantitative", "field": "long_"}, {"type": "quantitative", "field": "deaths"}, {"type": "nominal", "field": "county"}, {"type": "nominal", "field": "date"}]}, "title": "COVID-19 Confirmed Cases and Deaths by County", "transform": [{"filter": {"selection": "selector194"}}]}]}, {"data": {"name": "data-fd04509db941667a67c477157cf14753"}, "mark": "bar", "encoding": {"color": {"condition": {"value": "steelblue", "selection": "selector194"}, "value": "grey"}, "x": {"type": "nominal", "field": "date"}, "y": {"type": "quantitative", "field": "confirmed_per100K"}}, "height": 200, "selection": {"selector194": {"type": "single", "encodings": ["x"]}}, "title": "Confirmed Cases per 100K", "width": 800}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-1cd5af0cac96245a3e05a86bb4ea5fc4": [{"fips": "36001", "2020-03-07": 0, "2020-03-08": 0, "2020-03-09": 0, "2020-03-10": 0, "2020-03-11": 0, "2020-03-12": 2, "2020-03-13": 2, "2020-03-14": 5, "2020-03-15": 11, "2020-03-16": 12, "2020-03-17": 23, "2020-03-18": 36, "2020-03-19": 43, "2020-03-20": 61}, {"fips": "36003", "2020-03-07": 0, "2020-03-08": 0, "2020-03-09": 0, "2020-03-10": 0, "2020-03-11": 0, "2020-03-12": 0, "2020-03-13": 0, "2020-03-14": 0, "2020-03-15": 0, "2020-03-16": 2, "2020-03-17": 2, "2020-03-18": 2, "2020-03-19": 2, "2020-03-20": 2}, {"fips": "36007", "2020-03-07": 0, "2020-03-08": 0, "2020-03-09": 0, "2020-03-10": 0, "2020-03-11": 0, "2020-03-12": 0, "2020-03-13": 0, "2020-03-14": 1, "2020-03-15": 1, "2020-03-16": 1, "2020-03-17": 1, "2020-03-18": 2, "2020-03-19": 2, "2020-03-20": 2}, {"fips": "36017", "2020-03-07": 0, "2020-03-08": 0, "2020-03-09": 0, "2020-03-10": 0, "2020-03-11": 0, "2020-03-12": 0, "2020-03-13": 0, "2020-03-14": 0, "2020-03-15": 0, "2020-03-16": 0, "2020-03-17": 0, "2020-03-18": 1, "2020-03-19": 1, "2020-03-20": 2} ...
