# %% [markdown]
# ## ![Delta Lake Tiny Logo](https://pages.databricks.com/rs/094-YMS-629/images/delta-lake-tiny-logo.png) Delta Lake

# %%
# %run "./Include"

# %%
display(spark.sql("SELECT * FROM {}.bronze_stream".format(databaseName)))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(spark.sql("select unit_num, max(cycle_time) FROM {}.bronze_stream group by unit_num order by unit_num".format(databaseName)))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(spark.sql("SELECT Count(*) FROM {}.bronze_stream".format(databaseName)))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>20631</td></tr></tbody></table></div>

# %%
display(spark.sql("DESCRIBE HISTORY  {}.bronze_stream".format(databaseName)))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#The table name, path, database info are stored in Hive metastore, the actual schema is stored in the _delta_log directory
detail_df = spark.sql("DESCRIBE DETAIL  {}.bronze_stream".format(databaseName))
display(detail_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th></tr></thead><tbody><tr><td>delta</td><td>77f1e876-ab0c-4b45-9b3b-6bae9194b814</td><td>anindita.bronze_stream</td><td>null</td><td>dbfs:/anindita/sensor/bronze</td><td>2020-04-19T23:12:29.032+0000</td><td>2020-04-19T23:14:50.000+0000</td><td>List()</td><td>15</td><td>1016909</td><td>Map()</td><td>1</td><td>2</td></tr></tbody></table></div>

# %%
display(dbutils.fs.ls(bronzeOutPath + "/_delta_log"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sh cat /dbfs/anindita/sensor/bronze/_delta_log/00000000000000000000.json | head -4
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#34;commitInfo&#34;:{&#34;timestamp&#34;:1587337957132,&#34;userId&#34;:&#34;100785&#34;,&#34;userName&#34;:&#34;anindita.mahapatra@databricks.com&#34;,&#34;operation&#34;:&#34;STREAMING UPDATE&#34;,&#34;operationParameters&#34;:{&#34;outputMode&#34;:&#34;Append&#34;,&#34;queryId&#34;:&#34;68dd4128-746e-482b-959d-eb80b6e7dba2&#34;,&#34;epochId&#34;:&#34;0&#34;},&#34;notebook&#34;:{&#34;notebookId&#34;:&#34;1215371&#34;},&#34;clusterId&#34;:&#34;0419-220725-dowry112&#34;,&#34;isolationLevel&#34;:&#34;WriteSerializable&#34;,&#34;isBlindAppend&#34;:true}}
# ...

# %% [markdown]
# <a href="$./2-Data Refinement">Link to 2-Data Refinement</a>
