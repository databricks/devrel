# %% [markdown]
# # Python Fundamentals
#
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) In this lesson you:<br>
#  - Learn Python Fundamentals
#    * Variables
#    * Print statements
#    * Lists
#    * For Loops
#    * Functions
#    * Conditional Statements
#    * Types and Type Checking
#
# This is a good [reference sheet](http://www.cogsci.rpi.edu/~destem/igd/python_cheat_sheet.pdf) to bookmark. If you want a comprehensive tutorial on how you can use Python, check out this [official tutorial](https://docs.python.org/3/tutorial/) from the Python website.

# %% [markdown]
# ### Numbers: Using Python as your calculator!

# %%
# Hit the run button, or shift + enter
123456/8
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[39]: 15432.0</div>

# %%
# try giving Python the hardest math problem
2^568
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: 570</div>

# %% [markdown]
# ### Strings

# %%
'Ice cream' 'is paradise'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: &#39;Ice creamis paradise&#39;</div>

# %%
'Ice cream' + 'is paradise'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: &#39;Ice creamis paradise&#39;</div>

# %% [markdown]
# ### Lists
#
# Let's make a list of what everyone ate for breakfast this morning.
#
# <img src="https://www.simplyrecipes.com/wp-content/uploads/2018/06/Scrambled-Eggs-2.jpg" width="20%" height="10%">

# %%
breakfast_list = ["pancakes", "eggs", "waffles"]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Let's get the first breakfast element from this list.
#
# **Note:** Everything in Python is 0-indexed, so the first element is at position 0.

# %%
breakfast_list[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: &#39;pancakes&#39;</div>

# %% [markdown]
# Let's get the last breakfast item from this list.

# %%
breakfast_list[-1]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: &#39;waffles&#39;</div>

# %% [markdown]
# What if I want the second breakfast item and onwards?

# %%
breakfast_list[1:]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: [&#39;eggs&#39;, &#39;waffles&#39;]</div>

# %% [markdown]
# ### 1) Variables
#
# As Shakespeare famously wrote: `A rose by any other name would smell as sweet`. A variable in Python simply holds a value - you can call it any name you want (within reason...)!

# %%
simple_math = 8*50
simple_math
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: 400</div>

# %%
best_food = 'Ice cream'
best_food
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: &#39;Ice cream&#39;</div>

# %% [markdown]
# ### 2) Print Statements
#
# In Databricks/Jupyter notebooks, it will automatically print out the last line of the cell that it evaluates.
#
# However, we can force it to print out other components by using a `print` statement.

# %%
print("Hi there, tell me your hard math answer and the best food.")
print(simple_math)
print(best_food)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Hi there, tell me your hard math answer and the best food.
# 570
# Ice cream
# </div>

# %% [markdown]
# You can also be more explicit about what you are printing. You can add your variable within your print statement.

# %%
print(f"The answer to hard math is {simple_math}")
print(f"{best_food} is the best food on earth.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The answer to hard math is 570
# Ice cream is the best food on earth.
# </div>

# %% [markdown]
# Try printing this statement: `I need {simple_math} {best_food}`.

# %% [markdown]
# ### 3) Conditionals
#
# Sometimes, depending on certain conditions, we don't always want to execute every line of code. We can control this through using the `if`, `elif`, and `else` statements. Try changing `name` in the cell below and see the 3 different types of outputs.

# %%
best_food = "ice cream"
ice_cream_count = 1000

if best_food == "ice cream":
  print(f"I want {ice_cream_count} cones of ice cream.")
elif best_food == "":
  print("Tell us your favorite food")
else:
  print("Too bad. No ice cream")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">I want 1000 cones of ice cream.
# </div>

# %%
best_food = "chocolate"

if best_food == "ice cream":
  print(f"I want {ice_cream_count} cones of ice cream.")
elif best_food == "":
  print("Tell us your favorite food.")
else:
  print("Really? Isn't ice cream better?")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Really? Isn&#39;t ice cream better?
# </div>

# %% [markdown]
# d We want print plural forms of a food (try changing `food` to something else)! This requires adding an 's' to the end of a string only if it doesn't already have an 's' there.

# %%
best_food = "chocolate"

if best_food.endswith("s"):
  print(best_food)
else:
  print(best_food + "s")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">chocolates
# </div>

# %% [markdown]
# d ### 4) For Loops
#
# What if we wanted to print every breakfast we had this morning?
#
# Loops are a way to repeat a block of code while iterating over a sequence ("for-loop")

# %%
for food in breakfast_list:
  print(food)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">pancakes
# eggs
# waffles
# </div>

# %% [markdown]
# What if I want to count how many letters are there in each word?

# %%
for food in breakfast_list:
  print(f"{food} has {len(food)} letters.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">pancakes has 8 letters.
# eggs has 4 letters.
# waffles has 7 letters.
# </div>

# %% [markdown]
# ### 5) Functions
#
# The code above only works with `breakfast_list` but we can generalize it to work with different lists by making a function! A `function` is created with the `def` keyword and uses `return` to give its output.

# %%
# General syntax
# def function_name(parameter_name):
#   block of code that is run every time function is called

# defining the function
def print_length(breakfast_list):
  """
  breakfast_list is a variable that we can use within the function code
  """
  for food in breakfast_list:
    print(f"{food} has {len(food)} letters.")

# execute the function by passing print_foods a list
print_length(breakfast_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">pancakes has 8 letters.
# eggs has 4 letters.
# waffles has 7 letters.
# </div>

# %%
breakfast_list = ["bacon", 'sausage', 'yoghurt']

print_length(breakfast_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">bacon has 5 letters.
# sausage has 7 letters.
# yoghurt has 7 letters.
# </div>

# %% [markdown]
# What if you worry you'd forget what the function needs to be computed? Annotate it! <br>
#
# Check out this [reference](https://docs.python.org/3/tutorial/controlflow.html#function-annotations) if you want to learn more!
#
# As you can see below, annotating it doesn't affect how the function works at all. But it helps you to recall what the function takes in and outputs later!

# %%
def print_length(breakfast_list: 'list') -> 'string':
  """
  breakfast_list is a variable that we can use within the function code
  """
  for food in breakfast_list:
    print(f"{food} has {len(food)} letters.")
    
    
print_length(breakfast_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">bacon has 5 letters.
# sausage has 7 letters.
# yoghurt has 7 letters.
# </div>

# %% [markdown]
# ### 6) Functions with Multiple Arguments
#
# Let's define a function that will add two numbers together.

# %%
ice_cream_count = 1000
chocolate_count = 500

def count_fav_food(x, y):
  total = x + y
  return total

# count_fav_food(x = ice_cream_count, y = chocolate_count)
count_fav_food(ice_cream_count, chocolate_count)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: 1500</div>

# %% [markdown]
# What if you know that your `chocolate_count` is always going to be 500? You can set a default value!

# %%
def count_fav_food(x, y=500):
  total = x + y
  return total

count_fav_food(123)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: 623</div>

# %% [markdown]
# What if you want to calculate the proportion of food to approximately gauge how much you like each one?

# %%
def calculate_percentage(chocolate, ice_cream):
  percentage = chocolate / (ice_cream + chocolate) * 100
  return round(percentage, 2)

print(f"I like chocolate {calculate_percentage(985, 5123)}% of the time.")

percent = calculate_percentage(985, 5123)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">I like chocolate 16.13% of the time.
# </div>

# %% [markdown]
# Without function annotation...

# %%
help(count_fav_food)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Help on function count_fav_food in module __main__:
#
# count_fav_food(x, y=500)
#
# </div>

# %% [markdown]
# With function annotation...

# %%
help(print_length)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Help on function print_length in module __main__:
#
# print_length(breakfast_list: &#39;list&#39;) -&gt; &#39;string&#39;
#     breakfast_list is a variable that we can use within the function code
#
# </div>

# %% [markdown]
# ### 7) Types and Type Checking
#
# We have been defining quite a number of variables. What if we forget what types are the variables? Don't worry -- we can always check!
#
# Here are some of the variables we have defined:
# 0. `simple_math`
# 0. `percent`
# 0. `best_food`
# 0. `breakfast_list`

# %%
type(simple_math)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: int</div>

# %%
type(percent)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: float</div>

# %%
type(best_food)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[27]: str</div>

# %%
type(breakfast_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: list</div>

# %% [markdown]
# Let's define a new variable.

# %%
YouAreCool = True
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print("She is cool.", YouAreCool)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">She is cool. True
# </div>

# %%
type(YouAreCool)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[31]: bool</div>

# %% [markdown]
# You can also check the equality of the variables by using `==` (equal) or `!=` (not equal).

# %%
YouAreCool != False
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[32]: True</div>

# %%
best_food == 'ice cream'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[33]: False</div>

# %%
best_food
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: &#39;chocolate&#39;</div>

# %% [markdown]
# Summary of types:
# 0. An `int` is a numeric type in Python. It is an integer, so a whole number without decimals.
# 0. A `float` is a numeric type in Python. It is basically a number that has decimal places.
# 0. A `String` type is a sequence of characters, such as the food `"chocolate"`. It can be any sequence of characters too, not just words. `"Hello123"` or even `"123"` could also be a string. They are enclosed in quotes.
# 0. A `Boolean` type is either True or False.

# %% [markdown]
# ### 8) Append to List / Remove from List
#
# You can add more items to a list later if you wish as well!

# %%
breakfast_list.append("milk")
breakfast_list
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: [&#39;bacon&#39;, &#39;sausage&#39;, &#39;yoghurt&#39;, &#39;milk&#39;]</div>

# %%
breakfast_list.remove("milk")
breakfast_list
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[37]: [&#39;bacon&#39;, &#39;sausage&#39;, &#39;yoghurt&#39;]</div>
