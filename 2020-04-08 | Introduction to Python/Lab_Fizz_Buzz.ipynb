# %% [markdown]
# # Fizz Buzz Lab
#
# * Write a function called `fizzBuzz` that takes in a number.
# * If the number is divisible by 3 print `Fizz`. If the number is divisible by 5 print `Buzz`. If it is divisible by both 3 and 5 print `FizzBuzz` on one line.
# * If the number is not divisible by 3 or 5, just print the number.
#
# HINT: Look at the modulo (`%`) operator.

# %%
# TODO

# %%
# ANSWER
def fizzBuzz(i):
  if (i % 5 == 0) and (i % 3 == 0):
    print("FizzBuzz")
  elif i % 5 == 0:
    print("Buzz")
  elif i % 3 == 0:
    print("Fizz")
  else:
    print(i)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# This function expects a numeric type. If it receives a different type, it will throw an error.
#
# * Add a check so that if the input to the function is not numeric (either `float` or `int`) print `Not a number`.
#
# HINT: Use the `type()` function.

# %%
# TODO

# %%
# ANSWER
def typeCheckFizzBuzz(i):
  if type(i) == int or type(i) == float:
    if (i % 5 == 0) and (i % 3 == 0):
      print("FizzBuzz")
    elif i % 5 == 0:
      print("Buzz")
    elif i % 3 == 0:
      print("Fizz")
    else:
      print(i)
  else:
    print("Not a number")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# But what if the argument passed to the function were a list of values? Write a function that accepts a list of inputs, and applies the function to each element in the list.
#
# A sample list is provided below to test your function.

# %%
my_list = [1, 1.56, 3, 5, 15, 30, 50, 77, "Hello"]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TODO

# %%
# ANSWER
def listFizzBuzz(my_list):
  for i in my_list:
    if (type(i) == int) or (type(i) == float):
      if (i % 5 == 0) and (i % 3 == 0):
        print("FizzBuzz")
      elif i % 5 == 0:
        print("Buzz")
      elif i % 3 == 0:
        print("Fizz")
      else:
        print(i)
    else:
      print("Not a number")
      
listFizzBuzz(my_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1
# 1.56
# Fizz
# Buzz
# FizzBuzz
# FizzBuzz
# Buzz
# 77
# Not a number
# </div>
